# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import textwrap
from collections import Counter
from sklearn import preprocessing
import numpy as np
import math

# %%
def wrap_labels(ax, width, break_long_words=False):
    labels = []
    for label in ax.get_yticklabels():
        text = label.get_text()
        labels.append(textwrap.fill(text, width=width,
                      break_long_words=break_long_words))
    ax.set_yticklabels(labels, rotation=0)

# %%
df = pd.read_csv('./heatmap_cons.csv')
df = df.replace(['group_05', 'group_06', 'group_07', 'group_08', 'group_09', 'group_10', 'group_11', 'group_12', 
                'group_13', 'group_14', 'group_15', 'group_16', 'group_17', 'group_18', 'group_19', 'group_20', 
                'group_21', 'group_22', 'group_23', 'group_24', 'group_25', 'group_26', 'group_27', 'group_28', 
                'group_29', 'group_30', 'group_31', 'group_32'],
               ['marchands', 'boulangers', 'bouchers', 
                'tonneliers', 'drapiers', 'tanneurs', 
                'cabaretiers', 'maçons', 'forgerons', 
                'tailleurs', 'bateliers', 'pelletiers', 
                'charpentiers', 'crieurs et mesureurs de vin', 
                'cordonniers', 'orfèvres', 'marchands de grains', 
                'jardiniers', 'pêcheurs', 'barbiers et baigneurs', 
                'sauniers', 'tisserands', 'gourmets et courtiers', 
                'charrons', 'regrattiers, cordiers et fruitiers', 
                'coltineurs de tonneaux', 'constructeurs de bateaux', 
                'huiliers meuniers et tondeurs de draps'])
columns = df['date'].sort_values().unique()
index = df['represents'].sort_values().unique()
df2 = pd.DataFrame(index=index, columns=columns)
for element in index :
    sub_df = df.loc[df['represents'] == element]
    for index, row in sub_df.iterrows() :
        df2.loc[row['represents'], row['date']] = row['authority']
        
df_out = df2
for index, row in df2.iterrows():
    ls_count =[]
    for element in df2.columns.to_list(): 
        to_count = df2.loc[index][element]
        #print(to_count)
        if type(to_count) != str :
            df_out.loc[index][element] = 0
        else:
            ls_count.append(to_count)
            decompte = Counter(ls_count)
            df_out.loc[index][element] = decompte[to_count]

# %%
df_out = df_out.apply(pd.to_numeric,errors='ignore')
df_out_norm = (df_out-df_out.mean())/df_out.std(axis=0)
df_out_norm['mean'] = df_out_norm.mean(axis=1)
df_out_norm = df_out_norm.sort_values(by=['mean'])
df_out_norm = df_out_norm.drop(columns='mean')
df_out_norm = df_out_norm.fillna(-0.512823)

# %%
df_out_norm
# Out:
#                                             1400      1401      1402  \
# barbiers et baigneurs                  -0.512823 -0.512823 -0.512823
# huiliers meuniers et tondeurs de draps -0.512823 -0.512823  1.880350
# regrattiers, cordiers et fruitiers     -0.512823 -0.512823 -0.512823
# crieurs et mesureurs de vin            -0.512823 -0.512823  1.880350
# pêcheurs                               -0.512823 -0.512823 -0.512823
# orfèvres                               -0.512823 -0.512823 -0.512823
# maçons                                 -0.512823 -0.512823 -0.512823
# tailleurs                              -0.512823 -0.512823 -0.512823
# coltineurs de tonneaux                 -0.512823 -0.512823 -0.512823
# charpentiers                           -0.512823 -0.512823 -0.512823
# gourmets et courtiers                  -0.512823 -0.512823 -0.512823
# tisserands                             -0.512823 -0.512823  1.880350
# cordonniers                            -0.512823 -0.512823 -0.512823
# bateliers                              -0.512823 -0.512823  1.880350
# marchands                              -0.512823 -0.512823 -0.512823
# jardiniers                             -0.512823 -0.512823 -0.512823
# drapiers                               -0.512823 -0.512823 -0.512823
# constructeurs de bateaux               -0.512823 -0.512823 -0.512823
# cabaretiers                            -0.670028  0.244647  1.495575
# tanneurs                                0.773109 -0.897039 -1.296165
# marchands de grains                     0.773109 -0.897039  0.099705
# sauniers                                2.216246  0.244647  0.099705
# bouchers                                0.773109  0.244647  1.495575
# boulangers                             -0.670028  1.386334  0.099705
#
#                                             1410  ...      1490      1491  \
# barbiers et baigneurs                  -0.842927  ... -0.846575 -0.836784
# huiliers meuniers et tondeurs de draps  1.685854  ... -0.846575 -0.836784
# regrattiers, cordiers et fruitiers     -0.842927  ... -0.846575 -0.836784
# crieurs et mesureurs de vin             0.000000  ... -0.846575 -0.836784
# pêcheurs                               -0.842927  ...  0.682722 -0.502070
# orfèvres                               -0.842927  ...  0.300397  0.167357
# maçons                                  0.000000  ...  0.300397  0.502070
# tailleurs                              -0.842927  ... -0.081927  0.167357
# coltineurs de tonneaux                  1.685854  ... -0.846575 -0.836784
# charpentiers                            0.842927  ... -0.846575 -0.836784
# gourmets et courtiers                  -0.842927  ... -0.464251 -0.502070
# tisserands                             -0.842927  ... -0.846575 -0.836784
# cordonniers                             0.000000  ... -0.464251 -0.167357
# bateliers                              -0.842927  ...  1.065046  1.171498
# marchands                               0.000000  ... -0.081927 -0.502070
# jardiniers                             -0.842927  ... -0.464251 -0.167357
# drapiers                                0.842927  ... -0.081927 -0.502070
# constructeurs de bateaux                2.528782  ... -0.846575 -0.836784
# pelletiers                              0.842927  ... -0.081927  0.836784
# charrons                               -0.842927  ... -0.081927 -0.502070
# forgerons                               0.000000  ... -0.081927  0.167357
# tonneliers                             -0.842927  ...  2.594342  2.510352
# cabaretiers                            -0.842927  ... -0.464251 -0.167357
# tanneurs                                0.000000  ... -0.081927 -0.502070
# marchands de grains                    -0.842927  ... -0.081927  0.167357
# sauniers                                1.685854  ... -0.464251 -0.167357
# bouchers                                0.842927  ...  2.212018  2.175638
# boulangers                              0.000000  ...  2.594342  2.510352
#
#                                             1492      1493      1494  \
# barbiers et baigneurs                  -0.999790 -0.734847 -0.809953
# huiliers meuniers et tondeurs de draps -0.999790 -0.734847 -0.809953
# regrattiers, cordiers et fruitiers     -0.999790 -0.734847 -0.809953
# crieurs et mesureurs de vin            -0.999790 -0.734847 -0.809953
# pêcheurs                                0.191449 -0.367423 -0.220896
# orfèvres                                1.382689 -0.367423 -0.220896
# maçons                                 -0.404171  0.000000  0.073632
# tailleurs                               1.382689  0.000000  0.073632
# coltineurs de tonneaux                 -0.999790 -0.734847 -0.809953
# charpentiers                           -0.999790 -0.734847 -0.809953
# gourmets et courtiers                   0.787069  0.734847 -0.515425
# tisserands                             -0.999790 -0.734847 -0.809953
# cordonniers                            -0.404171  0.000000 -0.515425
# bateliers                              -0.404171  0.000000  0.073632
# marchands                               0.191449 -0.367423 -0.220896
# jardiniers                             -0.404171  0.000000 -0.515425
# drapiers                                0.191449  1.102270  0.957217
# constructeurs de bateaux               -0.999790 -0.734847 -0.809953
# pelletiers                              2.573929  0.367423  0.368161
# charrons                                0.191449 -0.367423 -0.220896
# forgerons                              -0.404171  0.000000  0.368161
# tonneliers                             -0.404171  0.000000 -0.515425
# cabaretiers                            -0.404171  0.000000  0.073632
# tanneurs                                0.191449  4.409082  3.607973
# marchands de grains                     1.382689  0.367423  0.368161
# sauniers                                1.978309 -0.367423  0.073632
# bouchers                                0.787069  0.734847  2.135331
# boulangers                             -0.404171  0.000000  1.251746
#
#                                             1495      1496      1497  \
# barbiers et baigneurs                  -0.970009 -1.053103 -0.936625
# huiliers meuniers et tondeurs de draps -0.970009 -1.053103 -0.936625
# regrattiers, cordiers et fruitiers     -0.970009 -1.053103 -0.936625
# crieurs et mesureurs de vin            -0.970009 -1.053103 -0.936625
# pêcheurs                                0.865143  1.755172 -0.422400
# orfèvres                                0.865143 -0.585057 -0.422400
# maçons                                  0.498113 -0.585057  0.091826
# tailleurs                               0.131082  0.819080 -0.422400
# coltineurs de tonneaux                 -0.970009 -1.053103 -0.936625
# charpentiers                           -0.970009 -1.053103 -0.936625
# gourmets et courtiers                  -0.235948 -0.585057  0.091826
# tisserands                             -0.970009 -1.053103 -0.936625
# cordonniers                            -0.235948 -0.585057  0.091826
# bateliers                               0.498113  0.351034  1.120278
# marchands                              -0.602979 -0.117011 -0.422400
# jardiniers                             -0.235948  1.287126  2.148729
# drapiers                               -0.602979 -0.117011 -0.422400
# constructeurs de bateaux               -0.970009 -1.053103 -0.936625
# pelletiers                             -0.602979 -0.117011 -0.422400
# charrons                                0.865143  1.755172 -0.422400
# forgerons                               0.865143  0.351034  1.120278
# tonneliers                             -0.235948  0.351034  1.120278
# cabaretiers                            -0.602979 -0.117011  0.091826
# tanneurs                                0.131082  0.819080  0.606052
# marchands de grains                     0.865143  1.755172 -0.422400
# sauniers                                0.498113  1.755172  2.662955
# bouchers                                3.067326 -0.585057  0.091826
# boulangers                              1.966234  0.819080  1.634503
#
#                                             1498      1499
# barbiers et baigneurs                  -0.948683 -1.122270
# huiliers meuniers et tondeurs de draps -0.948683 -1.122270
# regrattiers, cordiers et fruitiers     -0.948683 -1.122270
# crieurs et mesureurs de vin            -0.948683 -1.122270
# pêcheurs                                0.000000  0.027372
# orfèvres                                0.000000  0.027372
# maçons                                  0.000000  0.027372
# tailleurs                               0.000000  0.410587
# coltineurs de tonneaux                 -0.948683 -1.122270
# charpentiers                           -0.948683 -1.122270
# gourmets et courtiers                   0.000000  0.027372
# tisserands                             -0.948683 -1.122270
# cordonniers                            -0.474342 -0.355842
# bateliers                              -0.474342 -0.355842
# marchands                               0.000000  0.793801
# jardiniers                              0.474342  0.410587
# drapiers                                0.000000  0.027372
# constructeurs de bateaux               -0.948683 -1.122270
# pelletiers                              0.000000  1.560229
# charrons                               -0.474342  0.793801
# forgerons                               1.897367  1.560229
# tonneliers                              0.474342  0.410587
# cabaretiers                             0.948683 -0.739056
# tanneurs                                0.948683  0.027372
# marchands de grains                     0.000000  0.793801
# sauniers                               -0.474342 -0.355842
# bouchers                                1.423025  1.177015
# boulangers                              3.320392  2.709872
#
# [28 rows x 98 columns]

# %%
plt.figure(figsize=(15, 11), dpi=80)
heat = sns.heatmap(df_out_norm, vmin=-1, vmax=1)

heat.set_title("Carte de chaleur du pourvoiement des mandats de représentant au conseil par corporation (1400-1499)", loc='center')
heat.set_xlabel("année", fontsize = 20)
heat.set_ylabel("corporation", fontsize = 20)
wrap_labels(heat, 25)
fig = heat.get_figure()
fig.savefig('./Images/heatmapXV.svg', format='svg',bbox_inches='tight')
