# %% [markdown]
# Ce script permet de compiler les occurences des échevins des métiers des listes du conseil en un seul document.

# %%
import pandas as pd
import os

# %%
dfComp = pd.DataFrame(columns = ['Unnamed: 0','id', 'anneeMagistrature', 'magistrature', 'occurence', 'prenom', 'nom', 'surnom', 'genName', 'titres_roles', 'corps civique', 'corporation', 'poele', 'page', 'colonne', 'ligne'])
for filename in os.listdir('./../Sources/ListesConseil'):
    if filename.endswith('.csv'):
        with open(os.path.join('./../Sources/ListesConseil', filename)) as f:
            df = pd.read_csv(f)
            entry = df.loc[df['corps civique'] == 'echevinat']
            dfComp = dfComp.append([entry])
            dfComp = dfComp.sort_values(by=['id'])
    dfComp.to_csv('./Data/OccEch.csv',index=False)

# %%
dfComp
# Out:
#    Unnamed: 0                    id anneeMagistrature  \
# 4           5  aves_aa_4R_1400_0005              1400
# 29         30  aves_aa_4R_1400_0030              1400
# 30         31  aves_aa_4R_1400_0031              1400
# 31         32  aves_aa_4R_1400_0032              1400
# 32         33  aves_aa_4R_1400_0033              1400
# ..        ...                   ...               ...
# 26         27  aves_aa_4R_1499_0027              1499
# 27         28  aves_aa_4R_1499_0028              1499
# 28         29  aves_aa_4R_1499_0029              1499
# 29         30  aves_aa_4R_1499_0030              1499
# 30         31  aves_aa_4R_1499_0031              1499
#
#                   magistrature  \
# 4                    ammeister
# 29    conseiller_des_marchands
# 30   conseiller_des_boulangers
# 31     conseiller_des_bouchers
# 32     conseiller_des_drapiers
# ..                         ...
# 26  conseiller_des_cordonniers
# 27     conseiller_des_pêcheurs
# 28     conseiller_des_charrons
# 29   conseiller_des_jardiniers
# 30       conseiller_des_maçons
#
#                                             occurence     prenom          nom  \
# 4   her Wilhelm Metziger der                      ...    wilhelm     metziger
# 29                                  Hanman von Colmar  hannemann  colmar, von
# 30                              Gerung inn Judengasse        NaN       gerung
# 31                                  Wilhelm Rotschilt    wilhelm    rotschilt
# 32                                      Claus Spilman      claus    spielmann
# ..                                                ...        ...          ...
# 26  Martin Schultheiss genant Win und             ...     martin  schultheiss
# 27                                         Hans Rùser    johanns       russer
# 28                                     Marx Rebestock       marx    rebestock
# 29                                        Hans Bilger    johanns       bilger
# 30                                      Veltin Mynner     veltin       minner
#
#             surnom genName          titres_roles corps civique  \
# 4              NaN     NaN  ['her', 'ammeister']     echevinat
# 29             NaN     NaN                   NaN     echevinat
# 30  judengasse, in     NaN                   NaN     echevinat
# 31             NaN     NaN                   NaN     echevinat
# 32             NaN     NaN                   NaN     echevinat
# ..             ...     ...                   ...           ...
# 26             NaN     NaN                   NaN     echevinat
# 27             NaN     NaN                   NaN     echevinat
# 28             NaN     NaN                   NaN     echevinat
# 29             NaN     NaN                   NaN     echevinat
# 30             NaN     NaN                   NaN     echevinat
#
#                     corporation  poele page colonne ligne
# 4                           NaN    NaN  131       1     5
# 29    corporation_des_marchands    NaN  131       1    30
# 30   corporation_des_boulangers    NaN  131       1    31
# 31     corporation_des_bouchers    NaN  131       1    32
# 32     corporation_des_drapiers    NaN  131       1    33
# ..                          ...    ...  ...     ...   ...
# 26  corporation_des_cordonniers    NaN  220       2    29
# 27     corporation_des_pêcheurs    NaN  220       2    31
# 28     corporation_des_charrons    NaN  220       2    33
# 29   corporation_des_jardiniers    NaN  220       2    34
# 30       corporation_des_maçons    NaN  220       2    35
#
# [2650 rows x 16 columns]
