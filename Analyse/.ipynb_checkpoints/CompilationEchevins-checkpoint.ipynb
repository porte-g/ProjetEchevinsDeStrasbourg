# %% [markdown]
# Ce script permet de compiler les occurences des échevins des métiers des listes du conseil en un seul document.

# %%
import pandas as pd
import os

# %%
dfComp = pd.DataFrame(columns = ['id', 'anneeMagistrature', 'magistrature', 'occurence', 'prenom', 'nom', 'surnom', 'genName', 'titres_roles', 'corps civique', 'corporation', 'poele', 'page', 'colonne', 'ligne'])
for filename in os.listdir('./../Sources/ListesConseil'):
    if filename.endswith('.csv'):
        with open(os.path.join('./../Sources/ListesConseil', filename)) as f:
            df = pd.read_csv(f)
            entry = df.loc[df['corps civique'] == 'echevinat']
            dfComp = dfComp.append([entry])
            dfComp = dfComp.sort_values(by=['id'])
dfComp.reset_index(inplace=True)
dfComp = dfComp.rename(columns = {'index':'RangConseil'})
dfComp.to_csv('./Data/OccEch.csv',index=False)

# %%
dfComp
# Out:
#       RangConseil                    id anneeMagistrature  \
# 0               4  aves_aa_4R_1400_0005              1400
# 1              29  aves_aa_4R_1400_0030              1400
# 2              30  aves_aa_4R_1400_0031              1400
# 3              31  aves_aa_4R_1400_0032              1400
# 4              32  aves_aa_4R_1400_0033              1400
# ...           ...                   ...               ...
# 2641           26  aves_aa_4R_1499_0027              1499
# 2642           27  aves_aa_4R_1499_0028              1499
# 2643           28  aves_aa_4R_1499_0029              1499
# 2644           29  aves_aa_4R_1499_0030              1499
# 2645           30  aves_aa_4R_1499_0031              1499
#
#                     magistrature                               occurence  \
# 0                      ammeister      her Wilhelm Metziger der ammeister
# 1       conseiller_des_marchands                       Hanman von Colmar
# 2      conseiller_des_boulangers                   Gerung inn Judengasse
# 3        conseiller_des_bouchers                       Wilhelm Rotschilt
# 4        conseiller_des_drapiers                           Claus Spilman
# ...                          ...                                     ...
# 2641  conseiller_des_cordonniers  Martin Schultheiss genant Win und Brot
# 2642     conseiller_des_pêcheurs                              Hans Rùser
# 2643     conseiller_des_charrons                          Marx Rebestock
# 2644   conseiller_des_jardiniers                             Hans Bilger
# 2645       conseiller_des_maçons                           Veltin Mynner
#
#          prenom          nom          surnom genName          titres_roles  \
# 0       wilhelm     metziger             NaN     NaN  ['her', 'ammeister']
# 1     hannemann  colmar, von             NaN     NaN                   NaN
# 2           NaN       gerung  judengasse, in     NaN                   NaN
# 3       wilhelm    rotschilt             NaN     NaN                   NaN
# 4         claus    spielmann             NaN     NaN                   NaN
# ...         ...          ...             ...     ...                   ...
# 2641     martin  schultheiss   wein-und-brot     NaN                   NaN
# 2642    johanns       russer             NaN     NaN                   NaN
# 2643       marx    rebestock             NaN     NaN                   NaN
# 2644    johanns       bilger             NaN     NaN                   NaN
# 2645     veltin       minner             NaN     NaN                   NaN
#
#      corps civique                  corporation  poele page  colonne ligne
# 0        echevinat                          NaN    NaN  131      NaN     5
# 1        echevinat    corporation_des_marchands    NaN  131      NaN    30
# 2        echevinat   corporation_des_boulangers    NaN  131      NaN    31
# 3        echevinat     corporation_des_bouchers    NaN  131      NaN    32
# 4        echevinat     corporation_des_drapiers    NaN  131      NaN    33
# ...            ...                          ...    ...  ...      ...   ...
# 2641     echevinat  corporation_des_cordonniers    NaN  220      NaN    29
# 2642     echevinat     corporation_des_pêcheurs    NaN  220      NaN    31
# 2643     echevinat     corporation_des_charrons    NaN  220      NaN    33
# 2644     echevinat   corporation_des_jardiniers    NaN  220      NaN    34
# 2645     echevinat       corporation_des_maçons    NaN  220      NaN    35
#
# [2646 rows x 16 columns]
