# %% [markdown]
# # Import des modules

# %%
import pandas as pd
from bs4 import BeautifulSoup
from ast import literal_eval
import csv

# %% [markdown]
# # Création des variables

# %%
DF0 = pd.read_csv("./../Tables/ReferentielNoms.csv",converters={"FormesNonNormalisées": literal_eval}).set_index("NomNormalisé")
DF0
# Out:
#                           Types          FormesNonNormalisées  \
# NomNormalisé
# Ackerfuss        ['cognominal']         [Ackenfüs, Ackerfuss]
# Altzheim, von     ['toponymic']  [von Altzheim, Altzheim von]
# Amelung          ['cognominal']             [Amlung, Amelung]
# Anshelm          ['patronymic']                     [Anshelm]
# Arge             ['cognominal']            [Arge, Arg, Arige]
# ...                         ...                           ...
# Liebkint         ['cognominal']         [Liebekint, Liebkint]
# Sassbach          ['toponymic']          [Sahsbach, Sassbach]
# Claus            ['patronymic']                       [Claus]
# Spielmann      ['occupational']          [Spilman, Spielmann]
# Fürsenbach        ['toponymic']      [Fursenbach, Fürsenbach]
#
#               RenvoiToponymique
# NomNormalisé
# Ackerfuss                   NaN
# Altzheim, von               NaN
# Amelung                     NaN
# Anshelm                     NaN
# Arge                        NaN
# ...                         ...
# Liebkint                    NaN
# Sassbach                Sasbach
# Claus                       NaN
# Spielmann                   NaN
# Fürsenbach                  NaN
#
# [238 rows x 3 columns]

# %% [markdown]
# # Création de la soupe

# %%
soup = BeautifulSoup(open('./../Sources/EditionsXML/aves_aa_195_f69r-77r-v2.xml', 'r'))

# %% [markdown]
# # Création de la liste des éléments de la soupe à comparer

# %%
ListeNomsDoc = []
for surname in soup.find_all('surname'):
    ListeNomsDoc.append(surname.get_text())
print (ListeNomsDoc)
# Out:
# ['Schalck', 'Armbruster In Brantgasse', 'Amlung', 'Phige', 'Lumbart', 'Lumbart', 'Armbruster', 'Bisinger', 'Wissenburg', 'von Lutesheim', 'Hage', 'Merckel', 'Berner', 'Jude', 'Amlung', 'Rebe', 'Schaffener', 'Schultheiss', 'Erbe', 'Reb', 'Cüne', 'Lise', 'Wiss', 'Diether', 'Jeger', 'Hirse', 'Riffe', 'Voltz', 'Barpfennig', 'Barpfennig', 'Brucker', 'Riffe', 'Hapmacher', 'Böschwiller', 'Slempe', 'Scholle', 'von Seckingen', 'Wormsser', 'Stange', 'Stange', 'Würant', 'Menser', 'von Cölne', 'von Northus', 'Arge', 'Ofentürer', 'Dundenheim', 'Dundenheim', 'Sahsse', 'von Marle', 'Vilinger', 'Meistersheim', 'Rotschilt', 'von Berse', 'von Berse', 'Betscholt', 'von Hasela', 'Wormsser', 'Kalt', 'Volmar', 'Museler', 'Offenburg', 'Behtolt', 'Lügerlin', 'Dossenheim', 'Mesener', 'Ackenfüs', 'von Truhtersheim', 'Bömgarter', 'Brüder', 'Dossenheim', 'Stocker', 'Bömgarter', 'von Schaffoltzheim', 'von Hirtingheim', 'Armbruster', 'Lymer', 'Renner', 'Renner', 'von Belheim', 'Düringer', 'Düringer', 'Biderman', 'von Wantzen', 'Odertzheim', 'Steinbach', 'Weber', 'von Rore', 'Franckenheim', 'Kesselring', 'Melbrüge', 'von Nüfer', 'Kriegesheim', 'Stumpff', 'von Rore', 'Günter', 'Birböm', 'Griffe', 'Vendenheim', 'Metziger', 'Trachenfeils', 'Smerwer', 'Saltzmütter', 'Trachenfeils', 'Hitzvelder', 'Trachenfeils', 'Willekin', 'Siferman', 'Helle', 'von Crützenach', 'Leheman', 'von Ernoltzheim', 'Kannengiesser', 'Anshelm', 'Missebach', 'Newiller', 'Friburger', 'von Sletstat', 'Arige', 'Vegersheim', 'Clein', 'Lowe', 'Berner', 'Smalriem', 'Meister', 'Ott', 'von Sletstat', 'Snewel', 'Smalriem', 'von Mentz', 'von Molsheim', 'Glaser', 'Ernst', 'Glaser', 'von Altzheim', 'von Geistpoltzheim', 'Linser', 'von Ettenheim', 'Hapmacher', 'von Molsheim', 'Dür', 'Sporer', 'zü dem Tröschen', 'Sporer', 'Waldener', 'Franck', 'Zür Hellen', 'von Hagenowe', 'Wissensel', 'Spirer', 'Spirer', 'von Jenff', 'von Erffürt', 'Rosegart', 'von Ehenheim', 'von Ehenheim', 'Westerman', 'Dolde', 'Schanlit', 'Vetter', 'Bretteler', 'Dingesheim', 'Holtzhüser', 'Güngesheim', 'Dalheim', 'von Barre', 'Selig', 'Nefe', 'Duntzenheim', 'Bitsch', 'Lore', 'von Isenhusen', 'Lange', 'Kücheler', 'Mynner', 'Vendenheim', 'von Sant', 'von Molsheim', 'Schenck', 'Hafener', 'Seger', 'Brant', 'von Schuttern', 'Sidenfaden', 'züm Rade', 'von Ütenheim', 'von Worms', 'Kipkorn', 'Zerig', 'Rotgebe', 'Zoller', 'Eckendorff', 'Arnolt', 'Schrotbanck', 'Leistman', 'von Dürnyngen', 'Schrotbanck', 'von Lutern', 'von Mentz', 'Hüsz', 'von Sungouwe', 'Meiger', 'Vilinger', 'von Truhtersheim', 'Welsh', 'Rosenberg', 'Lembelin', 'Omeder', 'Erstenberg', 'Wideman', 'Glockengiesser', 'Wiszysen', 'Adam', 'Allewelt', 'von Belheim', 'Stückgarter', 'Hechede', 'von Heiligenstein', 'Stalle', 'Lötysen', 'Stüdel', 'Bintzel', 'Swartz', 'von Brümat', 'Wurtzgart', 'von Molsheim', 'Wolff', 'Müsung', 'Flach', 'Rorer', 'Rorer', 'Wolff', 'von Lampertheim', 'von Lampertheim', 'von Lampertheim', 'Kempff', 'von Mentze', 'Schaffener', 'Hügeler', 'Fründe', 'Knapp', 'Pfowe', 'Heiden', 'Hasenore', 'Bender', 'von Wile', 'Üsenberg', 'Smyt', 'Stumpf', 'Lehel', 'Günther', 'Kum noch Hint', 'von Wangen', 'Hennenberg', 'Götze', 'Flösz', 'Pfaffe', 'Butte', 'Ülrich', 'Röttel', 'Diebolt', 'Leheman', 'Suntheim', 'Lamb', 'Schertzheim', 'Lamb', 'Vachman', 'Münich', 'Lusche', 'Grave', 'Bentze', 'Klige', 'Hetteman', 'Klie', 'Dritzehen', 'Gerbott', 'Rinstett', 'Treger', 'Treger', 'Reinhart', 'Liebekint', 'Sahsbach', 'Claus', 'Spilman', 'Fursenbach', 'Kiebel', 'Spete', 'Clowe', 'Duntzenheim', 'Fleisch', 'Henckin', 'Drens', 'Peter', 'Lampreht', 'Hirte', 'Ersam', 'Kilwart', 'Mynne', 'Künig', 'Spiegel', 'Renner', 'Koch', 'Koch', 'Girbaden', 'Morung', 'von Wile', 'Wyldersynn', 'Hebenagel', 'von Than', 'von Korck', 'von Sletstat', 'Michel', 'Wipolt', 'Volmar', 'Volmar', 'Swencker', 'Götfrit', 'Herbest', 'Mittelhus', 'Butze', 'Kiebel', 'Porte', 'von Bergheim', 'Weidelich', 'von Gemer', 'von Molsheim', 'Ripel', 'Ripel', 'Ripel', 'Graseck', 'Winsticher', 'von Geispoltzheim', 'Swartz', 'von  ...

# %% [markdown]
# # Comparaison de la liste de la soupe à notre dataframe

# %%
for element in ListeNomsDoc :
    
    #Création des listes de références à partir du dataframe DF1.
    Colonne_FormesNonNormalisées = DF0['FormesNonNormalisées'].tolist()
    Colonne_NomNormalisé = DF0.index.tolist()
    Colonne_Types = DF0['Types'].tolist()
    
    #Vérification de l'existence de la forme non normalisée dans la liste des listes de formes non-normalisées.
    CheckSurnameNN = any(element in sublist for sublist in Colonne_FormesNonNormalisées)
    DicoPersonne = {}

    #Sinon, on demande un str en entrée pour le comparer à la liiste des formes normalisées.
    if CheckSurnameNN != True :
        SurnameN = input('Entrez la forme normalisée du nom ' + element + ' :')
        
        #Si l'entrée figure dans la liste des prénoms normalisées, on ajoute la forme non normalisée à la liste de celles-ci dans le dataframe.
        if SurnameN in Colonne_NomNormalisé:
            CelluleModif = DF0.loc[SurnameN, 'FormesNonNormalisées']
            #print(type(CelluleModif))
            #print(CelluleModif)
            CelluleModif.append(element)
            
        #Sinon, on crée un dataframe qu'on additionnera à l'existant.
        else :
            
            #On crée le couple 'PrénomNormalisé' dont la valeur correspond à la forme la plus courante du prénom.
            DicoPersonne['NomNormalisé'] = SurnameN
            
            #On crée le couple 'Types' dont la valeur est une liste contenant des tags proposant une description typologique du prénom.
            typologie = []
            n = int(input('Entrez le nombre de types à attribuer au nom ' + element + ' :'))
            for i in range(0,n):
                Type = input('Entrez un des types à attribuer au nom ' + element + ' :')
                typologie.append(Type)
            DicoPersonne['Types'] = typologie
            
            #On crée le couple 'FormesNonNormalisées' dont la valeur est une liste contenant toutes les formes alternatives du prénom.
            ListeNN = []
            ListeNN.append(element)
            if element != SurnameN :
                ListeNN.append(SurnameN)
            DicoPersonne['FormesNonNormalisées'] = ListeNN
            
            #On crée le couple 'RenvoiToponymique' dont la valeur est le nom normalisé en français (si possible) du lieu.
            for Type in typologie:
                if Type == 'toponymic':
                    RenvoiToponymique = input('Entrez le nom normalisé, en français si possible, du lieu auquel' + element + ' fait référence : ')
                    DicoPersonne['RenvoiToponymique'] = RenvoiToponymique
            
            #On crée le dataframe à ajouter à l'existant.
            DF1 = pd.DataFrame([DicoPersonne]).set_index('NomNormalisé')
            
            #On concatène le dictionnaire obtenu à notre Referentiel avant de recommencer toute l'opération.
            DF0 = pd.concat([DF0,DF1])
DF0
# Out:
# Entrez la forme normalisée du nom Kilwart :Kilwart
# Entrez le nombre de types à attribuer au nom Kilwart :1
# Entrez un des types à attribuer au nom Kilwart :occupational
# Entrez la forme normalisée du nom Mynne :Minner
# Entrez la forme normalisée du nom Künig :König
# Entrez le nombre de types à attribuer au nom Künig :1
# Entrez un des types à attribuer au nom Künig :cognominal
# Entrez la forme normalisée du nom Spiegel :Spiegel
# Entrez le nombre de types à attribuer au nom Spiegel :1
# Entrez un des types à attribuer au nom Spiegel :cognominal
# Entrez la forme normalisée du nom Koch :Koch
# Entrez le nombre de types à attribuer au nom Koch :1
# Entrez un des types à attribuer au nom Koch :occupational
# Entrez la forme normalisée du nom Girbaden :Girbaden
# Entrez le nombre de types à attribuer au nom Girbaden :1
# Entrez un des types à attribuer au nom Girbaden :toponymic
# Entrez le nom normalisé, en français si possible, du lieu auquelGirbaden fait référence : Guirbaden
# Entrez la forme normalisée du nom Morung :Morung
# Entrez le nombre de types à attribuer au nom Morung :0
# Entrez la forme normalisée du nom Wyldersynn :Wildersinn
# Entrez le nombre de types à attribuer au nom Wyldersynn :1
# Entrez un des types à attribuer au nom Wyldersynn :cognominal
# Entrez la forme normalisée du nom Hebenagel :Hebenagel
# Entrez le nombre de types à attribuer au nom Hebenagel :1
# Entrez un des types à attribuer au nom Hebenagel :cognominal
# Entrez la forme normalisée du nom von Than :Thann, von
# Entrez le nombre de types à attribuer au nom von Than :1
# Entrez un des types à attribuer au nom von Than :toponymic
# Entrez le nom normalisé, en français si possible, du lieu auquelvon Than fait référence : Thann
# Entrez la forme normalisée du nom von Korck :Korck, von
# Entrez le nombre de types à attribuer au nom von Korck :1
# Entrez un des types à attribuer au nom von Korck :toponymic
# Entrez le nom normalisé, en français si possible, du lieu auquelvon Korck fait référence : Kork
# Entrez la forme normalisée du nom Michel :Michel
# Entrez le nombre de types à attribuer au nom Michel :1
# Entrez un des types à attribuer au nom Michel :patronymic
# Entrez la forme normalisée du nom Wipolt :Wipolt
# Entrez le nombre de types à attribuer au nom Wipolt :1
# Entrez un des types à attribuer au nom Wipolt :patronymic
# Entrez la forme normalisée du nom Swencker :Schwencker
# Entrez le nombre de types à attribuer au nom Swencker :1
# Entrez un des types à attribuer au nom Swencker :cognominal
# Entrez la forme normalisée du nom Götfrit :Gottfried
# Entrez le nombre de types à attribuer au nom Götfrit :1
# Entrez un des types à attribuer au nom Götfrit :patronymic
# Entrez la forme normalisée du nom Herbest :Herbst
# Entrez le nombre de types à attribuer au nom Herbest :0
# Entrez la forme normalisée du nom Mittelhus :Mittelhaus
# Entrez le nombre de types à attribuer au nom Mittelhus :1
# Entrez un des types à attribuer au nom Mittelhus :toponymic
# Entrez le nom normalisé, en français si possible, du lieu auquelMittelhus fait référence : Mittelhausen
# Entrez la forme normalisée du nom Butze :Butze
# Entrez le nombre de types à attribuer au nom Butze :1
# Entrez un des types à attribuer au nom Butze :cognominal
# Entrez la forme normalisée du nom Porte :Porte
# Entrez le nombre de types à attribuer au nom Porte :0
# Entrez la forme normalisée du nom von Bergheim :Bergheim, von
# Entrez le nombre de types à attribuer au nom von Bergheim :1
# Entrez un des types à attribuer au nom von Bergheim :toponymic
# Entrez le nom normalisé, en français si possible, du lieu auquelvon Bergheim fait référence : Bergheim
# Entrez la forme normalisée du nom Weidelich :Weidlich
# Entrez le nombre de types à attribuer au nom Weidelich :1
# Entrez un des types à attribuer au nom Weidelich :cognominal
# Entrez la forme normalisée du nom von Gemer :Gemersheim, von
# Entrez le nombre de types à attribuer au nom von Gemer :1
# Entrez un des types à attribuer au nom von Gemer :toponymic
# Entrez le nom normalisé, en français si possible, du lieu auquelvon Gemer fait référence : Gemersheim
# Entrez la forme normalisée du nom Ripel :Rippel
# Entrez le nombre de types à attribuer au nom Ripel :1
# Entrez un des types à attribuer au nom Ripel :cognominal
# Entrez la forme normalisée du nom Graseck :Grasseck
# Entrez le nombre de types à attribuer au nom Graseck :1
# Entrez un des types à attribuer au nom Graseck :toponymic
# Entrez le nom normalisé, en français si possible, du lieu auquelGraseck fait référence :
# Entrez la forme normalisée du nom Winsticher :Winsticher
# Entrez le nombre de types à attribuer au nom Winsticher :1
# Entrez un des types à attribuer au nom Winsticher :occupational
# Entrez la forme normalisée du nom von Geispoltzheim :Geispoltzheim, von
# Entrez la forme normalisée du nom von Berckheim :Bergheim, von
# Entrez la forme normalisée du nom Walt :Walt
# Entrez le nombre de types à attribuer au nom Walt :1
# Entrez un des types à attribuer au nom Walt :toponymic
# Entrez le nom normalisé, en français si possible, du lieu auquelWalt fait référence :
# Entrez la forme normalisée du nom Ammeister :Ammeister
# Entrez le nombre de types à attribuer au nom Ammeister :1
# Entrez un des types à attribuer au nom Ammeister :occupational
# Entrez la forme normalisée du nom Estericher :Österreicher
# Entrez le nombre de types à attribuer au nom Estericher :1
# Entrez un des types à attribuer au nom Estericher :toponymic
# Entrez le nom normalisé, en français si possible, du lieu auquelEstericher fait référence : Autriche
# Entrez la forme normalisée du nom Ganser :Ganser
# Entrez le nombre de types à attribuer au nom Ganser :1
# Entrez un des types à attribuer au nom Ganser :occupational
# Entrez la forme normalisée du nom von Zabern :Zabern, von
# Entrez le nombre de types à attribuer au nom von Zabern :1
# Entrez un des types à attribuer au nom von Zabern :toponymic
# Entrez le nom normalisé, en français si possible, du lieu auquelvon Zabern fait référence : Saverne
# Entrez la forme normalisée du nom Smyde :Schmied
# Entrez la forme normalisée du nom Bösch :Bösch
# Entrez le nombre de types à attribuer au nom Bösch :0
# Entrez la forme normalisée du nom Wernlin :Wernlin
# Entrez le nombre de types à attribuer au nom Wernlin :1
# Entrez un des types à attribuer au nom Wernlin :patronymic
# Entrez la forme normalisée du nom Paulus :Paulus
# Entrez le nombre de types à attribuer au nom Paulus :1
# Entrez un des types à attribuer au nom Paulus :patronymic
# Entrez la forme normalisée du nom Hirt :Hirte
# Entrez la forme normalisée du nom Förster :Förster
# Entrez le nombre de types à attribuer au nom Förster :1
# Entrez un des types à attribuer au nom Förster :occupational
#                         Types          FormesNonNormalisées RenvoiToponymique
# NomNormalisé
# Ackerfuss      ['cognominal']         [Ackenfüs, Ackerfuss]               NaN
# Altzheim, von   ['toponymic']  [von Altzheim, Altzheim von]               NaN
# Amelung        ['cognominal']             [Amlung, Amelung]               NaN
# Anshelm        ['patronymic']                     [Anshelm]               NaN
# Arge           ['cognominal']            [Arge, Arg, Arige]               NaN
# ...                       ...                           ...               ...
# Zabern, von       [toponymic]     [von Zabern, Zabern, von]           Saverne
# Bösch                      []                       [Bösch]               NaN
# Wernlin          [patronymic]                     [Wernlin]               NaN
# Paulus           [patronymic]                      [Paulus]               NaN
# Förster        [occupational]                     [Förster]               NaN
#
# [281 rows x 3 columns]

# %%
DF0
# Out:
#                                                    Types  \
# NomNormalisé
# Ackerfuss                                 ['cognominal']
# Altzheim, von                              ['toponymic']
# Amelung                                   ['cognominal']
# Anshelm                                   ['patronymic']
# Arge                                      ['cognominal']
# Armbruster                              ['occupational']
# Armbruster in Brantgasse   ['occupational', 'toponymic']
# Arnolt                                    ['patronymic']
# Barpfennig                                ['cognominal']
# Barre, von                                 ['toponymic']
# Baumgarter                              ['occupational']
# Bechtolt                                  ['patronymic']
# Bellheim, von                              ['toponymic']
# Berner                                     ['toponymic']
# Berse, von                               ['toponymique']
# Bidermann                                 ['cognominal']
# Birbaum                                 ['occupational']
# Bisinger                                   ['toponymic']
# Bitsch                                                []
# Böschwiller                                ['toponymic']
# Brant                                     ['patronymic']
# Brettler                                ['occupational']
# Brucker                                               []
# Bruder                                    ['cognominal']
# Dahlheim                                   ['toponymic']
# Diether                                   ['patronymic']
# Dingsheim                                  ['toponymic']
# Dolde                                     ['cognominal']
# Dossenheim                                 ['toponymic']
# Dundenheim                                 ['toponymic']
# Duntzenheim                                ['toponymic']
# Düringer                                   ['toponymic']
# Dürningen, von                             ['toponymic']
# Dürr                                      ['cognominal']
# Eckendorf                                  ['toponymic']
# Ehenheim, von                              ['toponymic']
# Erbe                                      ['cognominal']
# Erfurt, von                                ['toponymic']
# Ernoltzheim, von                           ['toponymic']
# Ernst                                     ['patronymic']
# Ettenheim, von                             ['toponymic']
# Fergesheim                                 ['toponymic']
# Frank                                     ['cognominal']
# Frankenheim                                ['toponymic']
# Freiburger                                 ['toponymic']
# Geispoltzheim, von                         ['toponymic']
# Genf, von                                  ['toponymic']
# Gingsheim                                  ['toponymic']
# Glaser                                  ['occupational']
# Griffe                                  ['occupational']
# Günther                                   ['patronymic']
# Haffener                                ['occupational']
# Hage                                    ['occupational']
# Hagenau, von                               ['toponymic']
# Hapmacher                               ['occupational']
# Haslach von                                ['toponymic']
# Helle                                     ['cognominal']
# Hellen, zür                                ['toponymic']
# Hirse                                   ['occupational']
# Hirtzfelder                                ['toponymic']
# Holtzhauser                                ['toponymic']
# Hürtigheim, von                            ['toponymic']
# Isenhausen, von                            ['toponymic']
# Jäger                                   ['occupational']
# Jude                                      ['cognominal']
# Kalt                                      ['cognominal']
# Kannengiesser                           ['occupational']
# Kesselring                                ['cognominal']
# Kipkorn                                   ['cognominal']
# Klein                                     ['cognominal']
# Köln von                                   ['toponymic']
# Kreutzenach, von                           ['toponymic']
# Kriegsheim                                 ['toponymic']
# Kücheler                                ['occupational']
# Kühne                                     ['patronomyc']
# Lange                                     ['cognominal']
# Lehmann                                 ['occupational']
# Leimer                                     ['toponymic']
# Leistmann                               ['occupational']
# Leutesheim, von                            ['toponymic']
# Linzer                                     ['toponymic']
# Lise                                                  []
# Lore                                       ['toponymic']
# Löwe                                      ['cognominal']
# Lügerlin                                              []
# Lumbart                                    ['toponymic']
# Marlenheim, von                            ['toponymic']
# Meister                                 ['occupational']
# Meistersheim                               ['toponymic']
# Melbrühe                                  ['cognominal']
# Mentz von                                  ['toponymic']
# Mentzer                                    ['toponymic']
# Merckel                                   ['patronymic']
# Messner                                 ['occupational']
# Metziger                                ['occupational']
# Minner                                    ['cognominal']
# Missebach                                  ['toponymic']
# Molsheim, von                              ['toponymic']
# Müseler                                 ['occupational']
# Neffe                                     ['cognominal']
# Neuwiller                                  ['toponymic']
# Nordhuse, von                              ['toponymic']
# Nüffer, von                                ['toponymic']
# Odertzheim                                 ['toponymic']
# Ofentürer                               ['occupational']
# Offenburg                                  ['toponymic']
# Ott                                       ['patronymic']
# Phye                                                  []
# Rade, zum                                  ['toponymic']
# Rebe                                    ['occupational']
# Renner                                  ['occupational']
# Riffe                                                 []
# Rohr, von                                  ['toponymic']
# Rosegart                                   ['toponymic']
# Rotgebe                                 ['occupational']
# Rotschilt                                 ['cognominal']
# Sachse                                     ['toponymic']
# Säckingen, von                             ['toponymic']
# Saltzmütter                             ['occupational']
# Sant, von                                  ['toponymic']
# Schaeffolsheim, von                        ['toponymic']
# Schaffner                               ['occupational']
# Schalk                                  ['occupational']
# Schanlit                                              []
# Schenck                                 ['occupational']
# Schlempe                                ['occupational']
# Schlettstadt, von                          ['toponymic']
# Schmalriem                                ['cognominal']
# Schmerwer                                 ['cognominal']
# Schnebel                                  ['cognominal']
# Scholle                                               []
# Schrotbanck                             ['occupational']
# Schultheiss                             ['occupational']
# Schuttern, von                             ['toponymic']
# Seelig                                    ['cognominal']
# Seger                                   ['occupational']
# Seidenfaden                                         ['']
# Siffermann                                ['cognominal']
# Spirer                                     ['toponymic']
# Sporer                                  ['occupational']
# Stange                                                []
# Steinbach                                  ['toponymic']
# Stocker                                 ['occupational']
# Stumpf                    ['cognominal', 'occupational']
# Trachenfeils                                          []
# Tröschen, zum                              ['toponymic']
# Trüchtersheim, von                         ['toponymic']
# Uttenheim, von                             ['toponymic']
# Vendenheim                                 ['toponymic']
# Vetter                                  ['occupational']
# Villinger                                  ['toponymic']
# Volkmar                                    ['toponymic']
# Voltz                                                 []
# Waldener                                ['occupational']
# Wantzen, von                               ['toponymic']
# Weber                                   ['occupational']
# Weiss                                     ['cognominal']
# Westermann                                 ['toponymic']
# Willekin                                  ['patronymic']
# Wissenburg                                 ['toponymic']
# Wissensel                                 ['cognominal']
# Worms, von                                 ['toponymic']
# Wormser                                    ['toponymic']
# Würant                                                []
# Zerig                                   ['occupational']
# Zoller                                  ['occupational']
# Lautern, von                               ['toponymic']
# Hüss                                    ['occupational']
# Sundgau, von                               ['toponymic']
# Meiger                                  ['occupational']
# Welsch                                     ['toponymic']
# Rosenberg                                  ['toponymic']
# Lembelin                                              []
# Ohmeter                                 ['occupational']
# Erstenberg                                 ['toponymic']
# Weidemann                               ['occupational']
# Glockengiesser                          ['occupational']
# Weisseisen                              ['occupational']
# Adam                                      ['patronymic']
# Allewelt                                  ['cognominal']
# Stückgarter                             ['occupational']
# Heschde                                               []
# Heiligenstein, von                         ['toponymic']
# Stalle                                  ['occupational']
# Loteisen                                ['occupational']
# Studel                                                []
# Bintzel                                               []
# Schwartz                                  ['cognominal']
# Brümath, von                               ['toponymic']
# Wurtzgart                               ['occupational']
# Wolf                                      ['patronymic']
# Müsung                                                []
# Flach                                     ['cognominal']
# Rohrer                                     ['toponymic']
# Lampertheim, von                           ['toponymic']
# Kempf                                                 []
# Mentz, von                                 ['toponymic']
# Hügeler                                    ['toponymic']
# Freunde                                   ['cognominal']
# Knap                                      ['cognominal']
# Pfaue                                     ['cognominal']
# Heide                                     ['cognominal']
# Hasenohr                                  ['cognominal']
# Bender                                  ['occupational']
# Wile, von                                  ['toponymic']
# Üsenberg                                   ['toponymic']
# Schmied                                 ['occupational']
# Lehel                                                 []
# Komm nach Hinten                          ['cognominal']
# Wangen, von                                ['toponymic']
# Hennenberg                                 ['toponymic']
# Götze                                     ['patronymic']
# Flöss                                                 []
# Pfaffe                                  ['occupational']
# Butte                                                 []
# Ülrich                                    ['patronymic']
# Röttel                                                []
# Diebolt                                   ['patronymic']
# Sundheim                                   ['toponymic']
# Lamb                                      ['cognominal']
# Schertzheim                                ['toponymic']
# Fachmann                                ['occupational']
# Münch                                   ['occupational']
# Lusche                                    ['cognominal']
# Graff                                   ['occupational']
# Bentz                                     ['patronymic']
# Klige                                   ['occupational']
# Hettmann                                  ['patronymic']
# Dreitzehn                                 ['cognominal']
# Gerboth                                   ['patronymic']
# von Rheinstett                             ['toponymic']
# Träger                                  ['occupational']
# Reinhart                                  ['patronymic']
# Liebkint                                  ['cognominal']
# Sassbach                                   ['toponymic']
# Claus                                     ['patronymic']
# Spielmann                               ['occupational']
# Fürsenbach                                 ['toponymic']
# Kiebel                                    [occupational]
# Spette                                    [occupational]
# Claue                                       [cognominal]
# Fleisch                                   [occupational]
# Henneckin                                   [patronymic]
# Drens                                                 []
# Peter                                       [patronymic]
# Lamprecht                                   [patronymic]
# Hirte                                     [occupational]
# Ersame                                      [cognominal]
# Kilwart                                   [occupational]
# König                                       [cognominal]
# Spiegel                                     [cognominal]
# Koch                                      [occupational]
# Girbaden                                     [toponymic]
# Morung                                                []
# Wildersinn                                  [cognominal]
# Hebenagel                                   [cognominal]
# Thann, von                                   [toponymic]
# Korck, von                                   [toponymic]
# Michel                                      [patronymic]
# Wipolt                                      [patronymic]
# Schwencker                                  [cognominal]
# Gottfried                                   [patronymic]
# Herbst                                                []
# Mittelhaus                                   [toponymic]
# Butze                                       [cognominal]
# Porte                                                 []
# Bergheim, von                                [toponymic]
# Weidlich                                    [cognominal]
# Gemersheim, von                              [toponymic]
# Rippel                                      [cognominal]
# Grasseck                                     [toponymic]
# Winsticher                                [occupational]
# Walt                                         [toponymic]
# Ammeister                                 [occupational]
# Österreicher                                 [toponymic]
# Ganser                                    [occupational]
# Zabern, von                                  [toponymic]
# Bösch                                                 []
# Wernlin                                     [patronymic]
# Paulus                                      [patronymic]
# Förster                                   [occupational]
#
#                                                        FormesNonNormalisées  \
# NomNormalisé
# Ackerfuss                                             [Ackenfüs, Ackerfuss]
# Altzheim, von                                  [von Altzheim, Altzheim von]
# Amelung                                                   [Amlung, Amelung]
# Anshelm                                                           [Anshelm]
# Arge                                                     [Arge, Arg, Arige]
# Armbruster                                                     [Armbruster]
# Armbruster in Brantgasse  [Armbruster In Brantgasse, Armbruster in Brant...
# Arnolt                                                             [Arnolt]
# Barpfennig                                                     [Barpfennig]
# Barre, von                                          [von Barre, Barre, von]
# Baumgarter                                          [Bömgarter, Baumgarter]
# Bechtolt                                     [Betscholt, Bechtolt, Behtolt]
# Bellheim, von                                   [von Belheim, Bellheim von]
# Berner                                                             [Berner]
# Berse, von                                           [von Berse, Berse von]
# Bidermann                                             [Biderman, Bidermann]
# Birbaum                                                   [Birböm, Birbaum]
# Bisinger                                                         [Bisinger]
# Bitsch                                                             [Bitsch]
# Böschwiller                                      [Böschwiller, Bischwiller]
# Brant                                                               [Brant]
# Brettler                                              [Bretteler, Brettler]
# Brucker                                                  [Brucker, Brücker]
# Bruder                                                     [Brüder, Bruder]
# Dahlheim                                                [Dalheim, Dahlheim]
# Diether                                                  [Diether, Diether]
# Dingsheim                                           [Dingesheim, Dingsheim]
# Dolde                                                               [Dolde]
# Dossenheim                                                     [Dossenheim]
# Dundenheim                                                     [Dundenheim]
# Duntzenheim                                                   [Duntzenheim]
# Düringer                                                         [Düringer]
# Dürningen, von                              [von Dürnyngen, Dürningen, von]
# Dürr                                                            [Dür, Dürr]
# Eckendorf                                           [Eckendorff, Eckendorf]
# Ehenheim, von                                  [von Ehenheim, Ehenheim von]
# Erbe                                                                 [Erbe]
# Erfurt, von                                       [von Erffürt, Erfurt von]
# Ernoltzheim, von                         [von Ernoltzheim, Ernoltzheim von]
# Ernst                                                               [Ernst]
# Ettenheim, von                               [von Ettenheim, Ettenheim von]
# Fergesheim                                         [Vegersheim, Fergesheim]
# Frank                                                       [Franck, Frank]
# Frankenheim                                     [Franckenheim, Frankenheim]
# Freiburger                                          [Friburger, Freiburger]
# Geispoltzheim, von        [von Geistpoltzheim, Geispoltzheim von, von Ge...
# Genf, von                                             [von Jenff, Genf von]
# Gingsheim                                           [Güngesheim, Gingsheim]
# Glaser                                                             [Glaser]
# Griffe                                                             [Griffe]
# Günther                                                   [Günter, Günther]
# Haffener                                                [Hafener, Haffener]
# Hage                                                            [Hage, Hag]
# Hagenau, von                                    [von Hagenowe, Hagenau von]
# Hapmacher                                                       [Hapmacher]
# Haslach von                                       [von Hasela, Haslach von]
# Helle                                                               [Helle]
# Hellen, zür                                        [Zür Hellen, Hellen zür]
# Hirse                                                               [Hirse]
# Hirtzfelder                                       [Hitzvelder, Hirtzfelder]
# Holtzhauser                                       [Holtzhüser, Holtzhauser]
# Hürtigheim, von                           [von Hirtingheim, Hürtigheim von]
# Isenhausen, von                            [von Isenhusen, Isenhausen, von]
# Jäger                                                        [Jeger, Jäger]
# Jude                                                                 [Jude]
# Kalt                                                                 [Kalt]
# Kannengiesser                                               [Kannengiesser]
# Kesselring                                                     [Kesselring]
# Kipkorn                                                           [Kipkorn]
# Klein                                                        [Clein, Klein]
# Köln von                                              [von Cölne, Köln von]
# Kreutzenach, von                          [von Crützenach, Kreutzenach von]
# Kriegsheim                                        [Kriegesheim, Kriegsheim]
# Kücheler                                                         [Kücheler]
# Kühne                                                         [Cüne, Kühne]
# Lange                                                               [Lange]
# Lehmann                                                  [Leheman, Lehmann]
# Leimer                                                      [Lymer, Leimer]
# Leistmann                                             [Leistman, Leistmann]
# Leutesheim, von                             [von Lutesheim, Leutesheim von]
# Linzer                                                     [Linser, Linzer]
# Lise                                                           [Lise, Lise]
# Lore                                                                 [Lore]
# Löwe                                                           [Lowe, Löwe]
# Lügerlin                                                         [Lügerlin]
# Lumbart                                                  [Lumbart, Lumbard]
# Marlenheim, von                                 [von Marle, Marlenheim von]
# Meister                                                           [Meister]
# Meistersheim                                                 [Meistersheim]
# Melbrühe                                               [Melbrüge, Melbrühe]
# Mentz von                                            [von Mentz, Mentz von]
# Mentzer                                                   [Menser, Mentzer]
# Merckel                                                  [Merckel, Merckel]
# Messner                                                  [Mesener, Messner]
# Metziger                                                         [Metziger]
# Minner                                              [Mynner, Minner, Mynne]
# Missebach                                                       [Missebach]
# Molsheim, von                                [von Molsheim, von Mollisheim]
# Müseler                                                  [Museler, Müseler]
# Neffe                                                         [Nefe, Neffe]
# Neuwiller                                             [Newiller, Neuwiller]
# Nordhuse, von                                   [von Northus, Nordhuse von]
# Nüffer, von                                         [von Nüfer, Nüffer von]
# Odertzheim                                                     [Odertzheim]
# Ofentürer                                            [Ofentürer, Ofentürer]
# Offenburg                                                       [Offenburg]
# Ott                                                                   [Ott]
# Phye                                                          [Phige, Phye]
# Rade, zum                                             [züm Rade, Rade, zum]
# Rebe                                                            [Rebe, Reb]
# Renner                                                             [Renner]
# Riffe                                                               [Riffe]
# Rohr, von                                              [von Rore, Rohr von]
# Rosegart                                                         [Rosegart]
# Rotgebe                                                           [Rotgebe]
# Rotschilt                                                       [Rotschilt]
# Sachse                                                     [Sahsse, Sachse]
# Säckingen, von                               [von Seckingen, Säckingen von]
# Saltzmütter                                                   [Saltzmütter]
# Sant, von                                             [von Sant, Sant, von]
# Schaeffolsheim, von                [von Schaffoltzheim, Schaeffolsheim von]
# Schaffner                                           [Schaffener, Schaffner]
# Schalk                                                    [Schalck, Schalk]
# Schanlit                                                         [Schanlit]
# Schenck                                                           [Schenck]
# Schlempe                                                 [Slempe, Schlempe]
# Schlettstadt, von                          [von Sletstat, Schlettstadt von]
# Schmalriem                                           [Smalriem, Schmalriem]
# Schmerwer                                              [Smerwer, Schmerwer]
# Schnebel                                                 [Snewel, Schnebel]
# Scholle                                                   [Scholle, Schole]
# Schrotbanck                                                   [Schrotbanck]
# Schultheiss                                                   [Schultheiss]
# Schuttern, von                              [von Schuttern, Schuttern, von]
# Seelig                                                      [Selig, Seelig]
# Seger                                                               [Seger]
# Seidenfaden                                       [Sidenfaden, Seidenfaden]
# Siffermann                                           [Siferman, Siffermann]
# Spirer                                                             [Spirer]
# Sporer                                                             [Sporer]
# Stange                                                             [Stange]
# Steinbach                                                       [Steinbach]
# Stocker                                                           [Stocker]
# Stumpf                                                    [Stumpff, Stumpf]
# Trachenfeils                                                 [Trachenfeils]
# Tröschen, zum                               [zü dem Tröschen, Tröschen zum]
# Trüchtersheim, von                    [von Truhtersheim, Trüchtersheim von]
# Uttenheim, von                               [von Ütenheim, Uttenheim, von]
# Vendenheim                                                     [Vendenheim]
# Vetter                                                             [Vetter]
# Villinger                                             [Vilinger, Villinger]
# Volkmar                                                   [Volmar, Volkmar]
# Voltz                                                               [Voltz]
# Waldener                                                         [Waldener]
# Wantzen, von                                     [von Wantzen, Wantzen von]
# Weber                                                               [Weber]
# Weiss                                                         [Wiss, Weiss]
# Westermann                                          [Westerman, Westermann]
# Willekin                                                         [Willekin]
# Wissenburg                                                     [Wissenburg]
# Wissensel                                                       [Wissensel]
# Worms, von                                          [von Worms, Worms, von]
# Wormser                                                 [Wormsser, Wormser]
# Würant                                                     [Würant, Würent]
# Zerig                                                               [Zerig]
# Zoller                                                             [Zoller]
# Lautern, von                                     [von Lutern, Lautern, von]
# Hüss                                                           [Hüsz, Hüss]
# Sundgau, von                                   [von Sungouwe, Sundgau, von]
# Meiger                                                             [Meiger]
# Welsch                                                      [Welsh, Welsch]
# Rosenberg                                                       [Rosenberg]
# Lembelin                                                         [Lembelin]
# Ohmeter                                                   [Omeder, Ohmeter]
# Erstenberg                                                     [Erstenberg]
# Weidemann                                              [Wideman, Weidemann]
# Glockengiesser                                             [Glockengiesser]
# Weisseisen                                           [Wiszysen, Weisseisen]
# Adam                                                                 [Adam]
# Allewelt                                                         [Allewelt]
# Stückgarter                                                   [Stückgarter]
# Heschde                                                  [Hechede, Heschde]
# Heiligenstein, von                  [von Heiligenstein, Heiligenstein, von]
# Stalle                                                             [Stalle]
# Loteisen                                                [Lötysen, Loteisen]
# Studel                                                     [Stüdel, Studel]
# Bintzel                                                           [Bintzel]
# Schwartz                                                 [Swartz, Schwartz]
# Brümath, von                                     [von Brümat, Brümath, von]
# Wurtzgart                                                       [Wurtzgart]
# Wolf                                                          [Wolff, Wolf]
# Müsung                                                             [Müsung]
# Flach                                                               [Flach]
# Rohrer                                                      [Rorer, Rohrer]
# Lampertheim, von                        [von Lampertheim, Lampertheim, von]
# Kempf                                                       [Kempff, Kempf]
# Mentz, von                                         [von Mentze, Mentz, von]
# Hügeler                                                           [Hügeler]
# Freunde                                                   [Fründe, Freunde]
# Knap                                                          [Knapp, Knap]
# Pfaue                                                        [Pfowe, Pfaue]
# Heide                                                       [Heiden, Heide]
# Hasenohr                                               [Hasenore, Hasenohr]
# Bender                                                             [Bender]
# Wile, von                                             [von Wile, Wile, von]
# Üsenberg                                                         [Üsenberg]
# Schmied                                              [Smyt, Schmied, Smyde]
# Lehel                                                               [Lehel]
# Komm nach Hinten                          [Kum noch Hint, Komm nach Hinten]
# Wangen, von                                       [von Wangen, Wangen, von]
# Hennenberg                                                     [Hennenberg]
# Götze                                                               [Götze]
# Flöss                                                        [Flösz, Flöss]
# Pfaffe                                                             [Pfaffe]
# Butte                                                               [Butte]
# Ülrich                                                             [Ülrich]
# Röttel                                                             [Röttel]
# Diebolt                                                           [Diebolt]
# Sundheim                                               [Suntheim, Sundheim]
# Lamb                                                                 [Lamb]
# Schertzheim                                                   [Schertzheim]
# Fachmann                                                [Vachman, Fachmann]
# Münch                                                       [Münich, Münch]
# Lusche                                                             [Lusche]
# Graff                                                        [Grave, Graff]
# Bentz                                                       [Bentze, Bentz]
# Klige                                                         [Klige, Klie]
# Hettmann                                               [Hetteman, Hettmann]
# Dreitzehn                                            [Dritzehen, Dreitzehn]
# Gerboth                                                  [Gerbott, Gerboth]
# von Rheinstett                                   [Rinstett, von Rheinstett]
# Träger                                                     [Treger, Träger]
# Reinhart                                                         [Reinhart]
# Liebkint                                              [Liebekint, Liebkint]
# Sassbach                                               [Sahsbach, Sassbach]
# Claus                                                               [Claus]
# Spielmann                                              [Spilman, Spielmann]
# Fürsenbach                                         [Fursenbach, Fürsenbach]
# Kiebel                                                             [Kiebel]
# Spette                                                      [Spete, Spette]
# Claue                                                        [Clowe, Claue]
# Fleisch                                                           [Fleisch]
# Henneckin                                              [Henckin, Henneckin]
# Drens                                                               [Drens]
# Peter                                                               [Peter]
# Lamprecht                                             [Lampreht, Lamprecht]
# Hirte                                                         [Hirte, Hirt]
# Ersame                                                      [Ersam, Ersame]
# Kilwart                                                           [Kilwart]
# König                                                        [Künig, König]
# Spiegel                                                           [Spiegel]
# Koch                                                                 [Koch]
# Girbaden                                                         [Girbaden]
# Morung                                                             [Morung]
# Wildersinn                                         [Wyldersynn, Wildersinn]
# Hebenagel                                                       [Hebenagel]
# Thann, von                                           [von Than, Thann, von]
# Korck, von                                          [von Korck, Korck, von]
# Michel                                                             [Michel]
# Wipolt                                                             [Wipolt]
# Schwencker                                           [Swencker, Schwencker]
# Gottfried                                              [Götfrit, Gottfried]
# Herbst                                                    [Herbest, Herbst]
# Mittelhaus                                          [Mittelhus, Mittelhaus]
# Butze                                                               [Butze]
# Porte                                                               [Porte]
# Bergheim, von                  [von Bergheim, Bergheim, von, von Berckheim]
# Weidlich                                              [Weidelich, Weidlich]
# Gemersheim, von                                [von Gemer, Gemersheim, von]
# Rippel                                                      [Ripel, Rippel]
# Grasseck                                                [Graseck, Grasseck]
# Winsticher                                                     [Winsticher]
# Walt                                                                 [Walt]
# Ammeister                                                       [Ammeister]
# Österreicher                                     [Estericher, Österreicher]
# Ganser                                                             [Ganser]
# Zabern, von                                       [von Zabern, Zabern, von]
# Bösch                                                               [Bösch]
# Wernlin                                                           [Wernlin]
# Paulus                                                             [Paulus]
# Förster                                                           [Förster]
#
#                                RenvoiToponymique
# NomNormalisé
# Ackerfuss                                    NaN
# Altzheim, von                                NaN
# Amelung                                      NaN
# Anshelm                                      NaN
# Arge                                         NaN
# Armbruster                                   NaN
# Armbruster in Brantgasse                     NaN
# Arnolt                                       NaN
# Barpfennig                                   NaN
# Barre, von                                  Barr
# Baumgarter                                   NaN
# Bechtolt                                     NaN
# Bellheim, von                           Bellheim
# Berner                                     Berne
# Berse, von                                   NaN
# Bidermann                                    NaN
# Birbaum                                      NaN
# Bisinger                                Bisingen
# Bitsch                                       NaN
# Böschwiller                          Bischwiller
# Brant                                        NaN
# Brettler                                     NaN
# Brucker                                      NaN
# Bruder                                       NaN
# Dahlheim                                Dahlheim
# Diether                                      NaN
# Dingsheim                              Dingsheim
# Dolde                                        NaN
# Dossenheim                            Dossenheim
# Dundenheim                            Dundenheim
# Duntzenheim                          Duntzenheim
# Düringer                                     NaN
# Dürningen, von                         Durningen
# Dürr                                         NaN
# Eckendorf                           Alteckendorf
# Ehenheim, von                            Obernai
# Erbe                                         NaN
# Erfurt, von                               Erfurt
# Ernoltzheim, von               Ernolsheim-Bruche
# Ernst                                        NaN
# Ettenheim, von                         Ettenheim
# Fergesheim                           Fergersheim
# Frank                                        NaN
# Frankenheim                                  NaN
# Freiburger                              Fribourg
# Geispoltzheim, von                  Geispolsheim
# Genf, von                                 Genève
# Gingsheim                              Gingsheim
# Glaser                                       NaN
# Griffe                                       NaN
# Günther                                      NaN
# Haffener                                     NaN
# Hage                                         NaN
# Hagenau, von                            Haguenau
# Hapmacher                                    NaN
# Haslach von                              Haslach
# Helle                                        NaN
# Hellen, zür                                  NaN
# Hirse                                        NaN
# Hirtzfelder                          Hirtzfelden
# Holtzhauser                                  NaN
# Hürtigheim, von                       Hurtigheim
# Isenhausen, von                      Issenhausen
# Jäger                                        NaN
# Jude                                         NaN
# Kalt                                         NaN
# Kannengiesser                                NaN
# Kesselring                                   NaN
# Kipkorn                                      NaN
# Klein                                        NaN
# Köln von                                 Cologne
# Kreutzenach, von                       Kreuznach
# Kriegsheim                            Kriegsheim
# Kücheler                                     NaN
# Kühne                                        NaN
# Lange                                        NaN
# Lehmann                                      NaN
# Leimer                                    Leimen
# Leistmann                                    NaN
# Leutesheim, von                       Leutesheim
# Linzer                             Linz am Rhein
# Lise                                         NaN
# Lore                                        Laar
# Löwe                                         NaN
# Lügerlin                                     NaN
# Lumbart                                Lombardie
# Marlenheim, von                       Marlenheim
# Meister                                      NaN
# Meistersheim                                 NaN
# Melbrühe                                     NaN
# Mentz von                                Mayence
# Mentzer                                  Mayence
# Merckel                                      NaN
# Messner                                      NaN
# Metziger                                     NaN
# Minner                                       NaN
# Missebach                               Mussbach
# Molsheim, von                           Molsheim
# Müseler                                      NaN
# Neffe                                        NaN
# Neuwiller                  Neuwiller-lès-Saverne
# Nordhuse, von                          Nordhouse
# Nüffer, von                               Niffer
# Odertzheim                            Odratzheim
# Ofentürer                                    NaN
# Offenburg                             Offenbourg
# Ott                                          NaN
# Phye                                         NaN
# Rade, zum                                    NaN
# Rebe                                         NaN
# Renner                                       NaN
# Riffe                                        NaN
# Rohr, von                                   Rohr
# Rosegart                                     NaN
# Rotgebe                                      NaN
# Rotschilt                                    NaN
# Sachse                                       NaN
# Säckingen, von                     Bad Säckingen
# Saltzmütter                                  NaN
# Sant, von                                   Sand
# Schaeffolsheim, von           Oberschaeffolsheim
# Schaffner                                    NaN
# Schalk                                       NaN
# Schanlit                                     NaN
# Schenck                                      NaN
# Schlempe                                     NaN
# Schlettstadt, von                       Sélestat
# Schmalriem                                   NaN
# Schmerwer                                    NaN
# Schnebel                                     NaN
# Scholle                                      NaN
# Schrotbanck                                  NaN
# Schultheiss                                  NaN
# Schuttern, von                         Schuttern
# Seelig                                       NaN
# Seger                                        NaN
# Seidenfaden                                  NaN
# Siffermann                                   NaN
# Spirer                                     Spire
# Sporer                                       NaN
# Stange                                       NaN
# Steinbach                              Steinbach
# Stocker                                      NaN
# Stumpf                                       NaN
# Trachenfeils                                 NaN
# Tröschen, zum                                NaN
# Trüchtersheim, von                 Truchtersheim
# Uttenheim, von                         Uttenheim
# Vendenheim                            Vendenheim
# Vetter                                       NaN
# Villinger                 Villingen-Schwenningen
# Volkmar                                      NaN
# Voltz                                        NaN
# Waldener                                     NaN
# Wantzen, von                        Wantzenau La
# Weber                                        NaN
# Weiss                                        NaN
# Westermann                                   NaN
# Willekin                                     NaN
# Wissenburg                           Wissembourg
# Wissensel                                    NaN
# Worms, von                                 Worms
# Wormser                                    Worms
# Würant                                       NaN
# Zerig                                        NaN
# Zoller                                       NaN
# Lautern, von                                 NaN
# Hüss                                         NaN
# Sundgau, von                             Sundgau
# Meiger                                       NaN
# Welsch                                       NaN
# Rosenberg                                    NaN
# Lembelin                                     NaN
# Ohmeter                                      NaN
# Erstenberg                                   NaN
# Weidemann                                    NaN
# Glockengiesser                               NaN
# Weisseisen                                   NaN
# Adam                                         NaN
# Allewelt                                     NaN
# Stückgarter                                  NaN
# Heschde                                      NaN
# Heiligenstein, von                 Heiligenstein
# Stalle                                       NaN
# Loteisen                                     NaN
# Studel                                       NaN
# Bintzel                                      NaN
# Schwartz                                     NaN
# Brümath, von                             Brumath
# Wurtzgart                                    NaN
# Wolf                                         NaN
# Müsung                                       NaN
# Flach                                        NaN
# Rohrer                                      Rohr
# Lampertheim, von                     Lampertheim
# Kempf                                        NaN
# Mentz, von                               Mayence
# Hügeler                               Hügelsheim
# Freunde                                      NaN
# Knap                                         NaN
# Pfaue                                        NaN
# Heide                                        NaN
# Hasenohr                                     NaN
# Bender                                       NaN
# Wile, von                                    NaN
# Üsenberg                                Üsenberg
# Schmied                                      NaN
# Lehel                                        NaN
# Komm nach Hinten                             NaN
# Wangen, von                Wangenbourg-Engenthal
# Hennenberg                                   NaN
# Götze                                        NaN
# Flöss                                        NaN
# Pfaffe                                       NaN
# Butte                                        NaN
# Ülrich                                       NaN
# Röttel                                       NaN
# Diebolt                                      NaN
# Sundheim                                Sundheim
# Lamb                                         NaN
# Schertzheim                           Scherzheim
# Fachmann                                     NaN
# Münch                                        NaN
# Lusche                                       NaN
# Graff                                        NaN
# Bentz                                        NaN
# Klige                                        NaN
# Hettmann                                     NaN
# Dreitzehn                                    NaN
# Gerboth                                      NaN
# von Rheinstett                      Rheinstetten
# Träger                                       NaN
# Reinhart                                     NaN
# Liebkint                                     NaN
# Sassbach                                 Sasbach
# Claus                                        NaN
# Spielmann                                    NaN
# Fürsenbach                                   NaN
# Kiebel                                       NaN
# Spette                                       NaN
# Claue                                        NaN
# Fleisch                                      NaN
# Henneckin                                    NaN
# Drens                                        NaN
# Peter                                        NaN
# Lamprecht                                    NaN
# Hirte                                        NaN
# Ersame                                       NaN
# Kilwart                                      NaN
# König                                        NaN
# Spiegel                                      NaN
# Koch                                         NaN
# Girbaden                               Guirbaden
# Morung                                       NaN
# Wildersinn                                   NaN
# Hebenagel                                    NaN
# Thann, von                                 Thann
# Korck, von                                  Kork
# Michel                                       NaN
# Wipolt                                       NaN
# Schwencker                                   NaN
# Gottfried                                    NaN
# Herbst                                       NaN
# Mittelhaus                          Mittelhausen
# Butze                                        NaN
# Porte                                        NaN
# Bergheim, von                           Bergheim
# Weidlich                                     NaN
# Gemersheim, von                       Gemersheim
# Rippel                                       NaN
# Grasseck
# Winsticher                                   NaN
# Walt
# Ammeister                                    NaN
# Österreicher                            Autriche
# Ganser                                       NaN
# Zabern, von                              Saverne
# Bösch                                        NaN
# Wernlin                                      NaN
# Paulus                                       NaN
# Förster                                      NaN

# %%
DF0.to_csv("./../Tables/ReferentielNoms.csv")

# %%
pd.set_option('display.max_rows', None)
