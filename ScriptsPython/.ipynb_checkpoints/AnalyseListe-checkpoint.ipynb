# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(open('../Sources/EditionsXML/aves_aa_195_f69r-77r.xml', 'r'))
ListeDicosPersonnes = []
for persname in soup.find_all('persname'):
    DicoPersonne = {}
    for surname in persname.find_all('surname'):
        DicoPersonne['nom'] = surname.get_text()
    for forename in persname.find_all('forename'):
        DicoPersonne['prénom'] = forename.get_text()
    for genname in persname.find_all('genname'):
        DicoPersonne['surnom'] = genname.get_text()
    for rolename in persname.find_all('rolename'):
        Roles = []
        Roles.append(rolename.get_text())
        DicoPersonne['fonction'] = Roles
    ListeDicosPersonnes.append(DicoPersonne)
print (ListeDicosPersonnes)
# Out:
# [{'nom': 'Schalck', 'prénom': 'Obrecht', 'fonction': ['der Ammeister']}, {'nom': 'Armbruster in Brantgasse', 'prénom': 'Conrat'}, {'nom': 'Ammelung', 'prénom': 'Hanns'}, {'nom': 'Phige', 'prénom': 'Reimbolt'}, {'nom': 'Lumbart', 'prénom': 'Hanns'}, {'nom': 'Lumbart', 'prénom': 'Stefan'}, {'prénom': 'Reimbolt'}, {'nom': 'Armbruster', 'prénom': 'Hanns', 'fonction': ['der Ratsherr']}, {'nom': 'Kibitz', 'prénom': 'Heinrich'}, {'nom': 'Bisinger', 'prénom': 'Heinrich'}, {'nom': 'Wissenburg', 'prénom': 'Hanns'}, {'nom': 'von Leutesheim', 'prénom': 'Hanns'}, {'nom': 'Hage', 'prénom': 'Jacob'}, {'nom': 'Merckel', 'prénom': 'Cüntzel'}, {'nom': 'Berner', 'prénom': 'Frantz'}, {'nom': 'Jude', 'prénom': 'Heinz'}, {'nom': 'Ammelung', 'prénom': 'Jacob'}, {'fonction': ['der Zinsmeister']}, {'nom': 'Rebe', 'prénom': 'Laulin'}, {'nom': 'Schaffener', 'prénom': 'Hanns'}, {'nom': 'Schultheiss', 'prénom': 'Pantheleon'}, {'nom': 'Erbe', 'prénom': 'Laulin'}, {'nom': 'Rebe', 'prénom': 'Hensel'}, {'nom': 'Cüne'}, {'nom': 'Cüne', 'prénom': 'Hensel'}, {'nom': 'Lisen', 'prénom': 'Heinrich'}, {'nom': 'Wiss', 'prénom': 'Peter'}, {'nom': 'Dietherich', 'prénom': 'Diebolt'}, {'nom': 'Jeger', 'prénom': 'Hanseman'}, {'nom': 'Hirse', 'prénom': 'Heinz'}, {'nom': 'Riffe', 'prénom': 'Adam', 'fonction': ['der Ratsherr']}, {'nom': 'Voltz', 'prénom': 'Peter', 'surnom': 'der Alte'}, {'nom': 'Barpfennig', 'prénom': 'Marx'}, {'nom': 'Barpfennig', 'prénom': 'Rudolf'}, {'nom': 'Brucker', 'prénom': 'Peter'}, {'nom': 'Riffe', 'prénom': 'Peter'}, {'nom': 'Hapmacher', 'prénom': 'Andres'}, {'nom': 'Boschwiller', 'prénom': 'Claus'}, {'nom': 'Slempe', 'prénom': 'Heinrich'}, {'nom': 'Scholle', 'prénom': 'Bernhart'}, {'nom': 'von Seckingen', 'prénom': 'Fridel'}, {'nom': 'Wormser', 'prénom': 'Jacob'}, {'nom': 'Stange', 'prénom': 'Erhart'}, {'nom': 'Stange', 'prénom': 'Gilge'}, {'nom': 'Wurant', 'prénom': 'Claus'}, {'nom': 'Menser', 'prénom': 'Hanns'}, {'nom': 'von Cölne', 'prénom': 'Peter'}, {'nom': 'von Northus', 'prénom': 'Hanns'}, {'nom': 'Arge', 'prénom': 'Peter'}, {'nom': 'Ofentürer', 'prénom': 'Peter'}, {'nom': 'Dundenheim', 'prénom': 'Hanns'}, {'nom': 'Dundenheim', 'prénom': 'Peter'}, {'nom': 'Sachse', 'prénom': 'Stefan'}, {'nom': 'von Marle', 'prénom': 'Diebolt'}, {'nom': 'Villinger', 'prénom': 'Erhart'}, {'nom': 'Meistersheim', 'prénom': 'Hanns', 'fonction': ['der Ratsherr']}, {'nom': 'Rotschilt', 'prénom': 'Wilhelm'}, {'nom': 'von Berse', 'prénom': 'Hanns'}, {'nom': 'von Berse', 'prénom': 'Conrat'}, {'nom': 'Betscholt', 'prénom': 'Wilhelm'}, {'nom': 'von Haslach', 'prénom': 'Mathis'}, {'nom': 'Wormser', 'prénom': 'Voltz'}, {'nom': 'Kalt', 'prénom': 'Hanns'}, {'nom': 'Volmar', 'prénom': 'Jacob'}, {'nom': 'Museler', 'prénom': 'Heinrich'}, {'nom': 'Offenburg', 'prénom': 'Götze'}, {'nom': 'Bechtolt', 'prénom': 'Hanns'}, {'nom': 'Lugerlin', 'prénom': 'Claus'}, {'nom': 'Dossenheim', 'prénom': 'Hug', 'fonction': ['Altammeister']}, {'nom': 'Mesener', 'prénom': 'Andres'}, {'nom': 'Ackenfuss', 'prénom': 'Claus'}, {'nom': 'von Truhtersheim', 'prénom': 'Eberhart'}, {'nom': 'Baumgartner', 'prénom': 'Erhart'}, {'nom': 'Bruder', 'prénom': 'Stoffelus'}, {'nom': 'Dossenheim', 'prénom': 'Claus'}, {'nom': 'Stocker', 'prénom': 'Heinrich'}, {'nom': 'Baumgartner', 'prénom': 'Claus', 'fonction': ['der Ratsherr']}, {'nom': 'von Shaffolsheim', 'prénom': 'Wilhelm'}, {'nom': 'von Hürtingheim', 'prénom': 'Fritsch'}, {'nom': 'Armbruster', 'prénom': 'Conrat', 'fonction': ['der Ratsherr']}, {'nom': 'Leimer', 'prénom': 'Heinrich'}, {'nom': 'Renner', 'prénom': 'Hanns', 'surnom': 'der Alte'}, {'nom': 'Renner', 'prénom': 'Hanns', 'surnom': 'der Junge'}, {'nom': 'von Belheim', 'prénom': 'Jacob'}, {'nom': 'Düringer', 'prénom': 'Cüne', 'surnom': 'der Alte'}, {'nom': 'Düringer', 'prénom': 'Cüne', 'surnom': 'der Junge'}, {'nom': 'Biderman', 'prénom': 'Claus'}, {'nom': 'von Wangen', 'prénom': 'Jacob'}, {'nom': 'Odratzheim', 'prénom': 'Hanns'}, {'nom': 'Steinbach', 'prénom': 'Hanns'}, {'nom': 'Werber', 'prénom': 'Cl ...

# %%
import pandas as pd
dataframe = pd.DataFrame(ListeDicosPersonnes)
print (dataframe)
# Out:
#                           nom     prénom         fonction    surnom
# 0                     Schalck    Obrecht  [der Ammeister]       NaN
# 1    Armbruster in Brantgasse     Conrat              NaN       NaN
# 2                    Ammelung      Hanns              NaN       NaN
# 3                       Phige   Reimbolt              NaN       NaN
# 4                     Lumbart      Hanns              NaN       NaN
# ..                        ...        ...              ...       ...
# 374                       NaN  Friderich   [der Kacheler]       NaN
# 375             von Durningen      Sigel   [der Ratsherr]       NaN
# 376                    Paulus      Hanns              NaN       NaN
# 377                      Hirt      Hanns              NaN  der Alte
# 378                   Förster     Symont              NaN       NaN
#
# [379 rows x 4 columns]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(dataframe)
# Out:
#                           nom      prénom            fonction     surnom
# 0                     Schalck     Obrecht     [der Ammeister]        NaN
# 1    Armbruster in Brantgasse      Conrat                 NaN        NaN
# 2                    Ammelung       Hanns                 NaN        NaN
# 3                       Phige    Reimbolt                 NaN        NaN
# 4                     Lumbart       Hanns                 NaN        NaN
# 5                     Lumbart      Stefan                 NaN        NaN
# 6                         NaN    Reimbolt                 NaN        NaN
# 7                  Armbruster       Hanns      [der Ratsherr]        NaN
# 8                      Kibitz    Heinrich                 NaN        NaN
# 9                    Bisinger    Heinrich                 NaN        NaN
# 10                 Wissenburg       Hanns                 NaN        NaN
# 11             von Leutesheim       Hanns                 NaN        NaN
# 12                       Hage       Jacob                 NaN        NaN
# 13                    Merckel     Cüntzel                 NaN        NaN
# 14                     Berner      Frantz                 NaN        NaN
# 15                       Jude       Heinz                 NaN        NaN
# 16                   Ammelung       Jacob                 NaN        NaN
# 17                        NaN         NaN   [der Zinsmeister]        NaN
# 18                       Rebe      Laulin                 NaN        NaN
# 19                 Schaffener       Hanns                 NaN        NaN
# 20                Schultheiss  Pantheleon                 NaN        NaN
# 21                       Erbe      Laulin                 NaN        NaN
# 22                       Rebe      Hensel                 NaN        NaN
# 23                       Cüne         NaN                 NaN        NaN
# 24                       Cüne      Hensel                 NaN        NaN
# 25                      Lisen    Heinrich                 NaN        NaN
# 26                       Wiss       Peter                 NaN        NaN
# 27                 Dietherich     Diebolt                 NaN        NaN
# 28                      Jeger    Hanseman                 NaN        NaN
# 29                      Hirse       Heinz                 NaN        NaN
# 30                      Riffe        Adam      [der Ratsherr]        NaN
# 31                      Voltz       Peter                 NaN   der Alte
# 32                 Barpfennig        Marx                 NaN        NaN
# 33                 Barpfennig      Rudolf                 NaN        NaN
# 34                    Brucker       Peter                 NaN        NaN
# 35                      Riffe       Peter                 NaN        NaN
# 36                  Hapmacher      Andres                 NaN        NaN
# 37                Boschwiller       Claus                 NaN        NaN
# 38                     Slempe    Heinrich                 NaN        NaN
# 39                    Scholle    Bernhart                 NaN        NaN
# 40              von Seckingen      Fridel                 NaN        NaN
# 41                    Wormser       Jacob                 NaN        NaN
# 42                     Stange      Erhart                 NaN        NaN
# 43                     Stange       Gilge                 NaN        NaN
# 44                     Wurant       Claus                 NaN        NaN
# 45                     Menser       Hanns                 NaN        NaN
# 46                  von Cölne       Peter                 NaN        NaN
# 47                von Northus       Hanns                 NaN        NaN
# 48                       Arge       Peter                 NaN        NaN
# 49                  Ofentürer       Peter                 NaN        NaN
# 50                 Dundenheim       Hanns                 NaN        NaN
# 51                 Dundenheim       Peter                 NaN        NaN
# 52                     Sachse      Stefan                 NaN        NaN
# 53                  von Marle     Diebolt                 NaN        NaN
# 54                  Villinger      Erhart                 NaN        NaN
# 55               Meistersheim       Hanns      [der Ratsherr]        NaN
# 56                  Rotschilt     Wilhelm                 NaN        NaN
# 57                  von Berse       Hanns                 NaN        NaN
# 58                  von Berse      Conrat                 NaN        NaN
# 59                  Betscholt     Wilhelm                 NaN        NaN
# 60                von Haslach      Mathis                 NaN        NaN
# 61                    Wormser       Voltz                 NaN        NaN
# 62                       Kalt       Hanns                 NaN        NaN
# 63                     Volmar       Jacob                 NaN        NaN
# 64                    Museler    Heinrich                 NaN        NaN
# 65                  Offenburg       Götze                 NaN        NaN
# 66                   Bechtolt       Hanns                 NaN        NaN
# 67                   Lugerlin       Claus                 NaN        NaN
# 68                 Dossenheim         Hug      [Altammeister]        NaN
# 69                    Mesener      Andres                 NaN        NaN
# 70                  Ackenfuss       Claus                 NaN        NaN
# 71           von Truhtersheim    Eberhart                 NaN        NaN
# 72                Baumgartner      Erhart                 NaN        NaN
# 73                     Bruder   Stoffelus                 NaN        NaN
# 74                 Dossenheim       Claus                 NaN        NaN
# 75                    Stocker    Heinrich                 NaN        NaN
# 76                Baumgartner       Claus      [der Ratsherr]        NaN
# 77           von Shaffolsheim     Wilhelm                 NaN        NaN
# 78            von Hürtingheim     Fritsch                 NaN        NaN
# 79                 Armbruster      Conrat      [der Ratsherr]        NaN
# 80                     Leimer    Heinrich                 NaN        NaN
# 81                     Renner       Hanns                 NaN   der Alte
# 82                     Renner       Hanns                 NaN  der Junge
# 83                von Belheim       Jacob                 NaN        NaN
# 84                   Düringer        Cüne                 NaN   der Alte
# 85                   Düringer        Cüne                 NaN  der Junge
# 86                   Biderman       Claus                 NaN        NaN
# 87                 von Wangen       Jacob                 NaN        NaN
# 88                 Odratzheim       Hanns                 NaN        NaN
# 89                  Steinbach       Hanns                 NaN        NaN
# 90                     Werber       Claus                 NaN        NaN
# 91                   von Rohr       Claus                 NaN        NaN
# 92               Franckenheim      Ottman                 NaN        NaN
# 93                 Kesselring       Hanns                 NaN        NaN
# 94                   Melbrüge       Hanns                 NaN        NaN
# 95                  von Nufer      Berman                 NaN        NaN
# 96                 Kriegsheim       Claus                 NaN        NaN
# 97                     Stumpf       Hanns      [der Ratsherr]        NaN
# 98                   von Rohr       Peter                 NaN        NaN
# 99                    Günther       Hanns                 NaN        NaN
# 100                  Birnbaum    Heinrich                 NaN        NaN
# 101                    Griffe    Heinrich                 NaN        NaN
# 102                Vendenheim       Claus                 NaN        NaN
# 103                  Metziger       Peter                 NaN        NaN
# 104               Trachenfels    Lienhart      [Altammeister]        NaN
# 105                   Smerwer      Andres                 NaN        NaN
# 106               Saltzmütter  Dietherman                 NaN        NaN
# 107               Trachenfels       Hanns                 NaN        NaN
# 108               Hirtzfelder       Hanns                 NaN        NaN
# 109               Trachenfels     Diebolt      [der Ratsherr]        NaN
# 110                  Willekin     Florenz                 NaN        NaN
# 111                  Siferman    Burckart                 NaN        NaN
# 112                     Helle      Veltin                 NaN        NaN
# 113             von Kreuznach       Hanns                 NaN        NaN
# 114                   Leheman    Heinrich                 NaN        NaN
# 115           von Ernoltzheim       Claus                 NaN        NaN
# 116             Kannengiesser       Claus                 NaN        NaN
# 117               in Krutenau       Mertz                 NaN        NaN
# 118                   Anshelm       Jerge                 NaN        NaN
# 119                 Missebach       Peter                 NaN        NaN
# 120                 Neuwiller       Hanns                 NaN        NaN
# 121                 Friburger       Jacob                 NaN        NaN
# 122          von Schlettstadt       Hanns                 NaN        NaN
# 123                      Arge       Peter                 NaN        NaN
# 124                Fegersheim       Hanns                 NaN        NaN
# 125                     Clein       Hanns       [Münzmeister]        NaN
# 126                      Löwe       Jacob                 NaN        NaN
# 127                    Berner       Peter                 NaN        NaN
# 128                  Smalriem      Andres                 NaN        NaN
# 129                     Hirtz         NaN           [meister]        NaN
# 130                       Ott       Hanns                 NaN        NaN
# 131          von Schlettstadt       Hanns      [der Ratsherr]        NaN
# 132                  Snewelin    Heinrich                 NaN        NaN
# 133                  Smalriem       Adolf                 NaN        NaN
# 134                 von Mentz       Claus                 NaN        NaN
# 135              von Molsheim       Hanns        [Armbruster]        NaN
# 136                    Glaser      Ulrich                 NaN        NaN
# 137                     Ernst      Martin                 NaN        NaN
# 138                    Glaser      Herzog                 NaN        NaN
# 139             von Altenheim       Hanns                 NaN        NaN
# 140          von Geispolsheim       Jacob      [Altammeister]        NaN
# 141                    Linser       Claus      [der Ratsherr]        NaN
# 142             von Ettenheim      Mathis                 NaN        NaN
# 143                 Hapmacher     Fritsch                 NaN        NaN
# 144              von Molsheim        Adam                 NaN        NaN
# 145                     Dürre     Walther                 NaN        NaN
# 146                    Sporer       Jacob                 NaN        NaN
# 147           zu dem Tröschen       Cuntz                 NaN        NaN
# 148                    Sporer       Hanns                 NaN        NaN
# 149                  Waldener       Jacob                 NaN        NaN
# 150                     Frank       Hanns                 NaN        NaN
# 151                     Gilge         NaN                 NaN        NaN
# 152                zur Hellen       Claus      [der Ratsherr]        NaN
# 153               von Hagenau       Götze                 NaN        NaN
# 154                 Wissensee       Claus                 NaN        NaN
# 155                    Spirer     Diebolt                 NaN        NaN
# 156                    Spirer       Hanns                 NaN        NaN
# 157                  von Genf       Hanns                 NaN        NaN
# 158                von Erfurt       Claus                 NaN        NaN
# 159                  Rosegart    Heinrich                 NaN        NaN
# 160              von Ehenheim      Symont                 NaN        NaN
# 161                    Hensel      Martin                 NaN        NaN
# 162                    Hensel      Martin                 NaN        NaN
# 163              von Ehenheim      Veltin                 NaN        NaN
# 164                 Westerman      Martin                 NaN        NaN
# 165                     Dolde      Laulin                 NaN        NaN
# 166                  Schanlit       Claus      [Altammeister]        NaN
# 167                    Vetter       Claus                 NaN        NaN
# 168                 Bretteler       Hanns                 NaN        NaN
# 169                 Dingsheim       Hanns                 NaN        NaN
# 170                Holtzhuser    Heinzman                 NaN        NaN
# 171           an Steinstrasse     Wernlin                 NaN        NaN
# 172                Gungesheim       Hanns                 NaN        NaN
# 173                   Dalheim       Hanns                 NaN        NaN
# 174                 von Barre       Claus                 NaN        NaN
# 175                     Selig       Peter                 NaN        NaN
# 176                       NaN     Marzolf                 NaN        NaN
# 177                     Neffe       Hanns                 NaN        NaN
# 178               Duntzenheim       Claus      [der Ratsherr]        NaN
# 179                    Bitsch       Hanns                 NaN        NaN
# 180                  von Lahr       Hanns                 NaN        NaN
# 181           von Issenhausen      Erhart                 NaN        NaN
# 182                     Lange       Claus                 NaN        NaN
# 183                  Kücheler       Claus                 NaN        NaN
# 184                    Minner       Hanns                 NaN        NaN
# 185                Vendenheim       Hanns                 NaN        NaN
# 186                  von Sant     Diebolt                 NaN        NaN
# 187              von Molsheim       Peter                 NaN        NaN
# 188                   Schenck       Hanns          [der Alte]        NaN
# 189                       NaN       Sitze  [der Stallmeister]        NaN
# 190                   Hafener       Jacob     [Kaufhausherre]        NaN
# 191                     Seger       Hanns      [der Ratsherr]        NaN
# 192                     Brant     Diebolt                 NaN        NaN
# 193             von Schuttern     Wilhelm                 NaN        NaN
# 194                Sidenfaden      Fridel                 NaN        NaN
# 195                   zum Rad    Bernhart                 NaN        NaN
# 196              von Utenheim       Hanns                 NaN        NaN
# 197                zur Kronen       Peter                 NaN        NaN
# 198                 von Worms      Alhelm                 NaN        NaN
# 199                   Kipkorn       Hanns        [Schaffener]        NaN
# 200                     Zerig      Syfrit      [der Ratsherr]        NaN
# 201                   Ratgebe       Jacob                 NaN        NaN
# 202                  Monschin         NaN                 NaN        NaN
# 203                    Zoller       Hanns                 NaN        NaN
# 204                 Eckendorf    Heinrich                 NaN        NaN
# 205                    Arnolt      Conrat                 NaN        NaN
# 206               Schrotbanck      Conrat                 NaN        NaN
# 207                  Leistman    Dietrich                 NaN        NaN
# 208             von Durningen    Heinrich                 NaN        NaN
# 209               Schrotbanck     Ortliep                 NaN        NaN
# 210                von Lutern       Hanns                 NaN        NaN
# 211                 von Mentz      Krafft                 NaN        NaN
# 212                      Hüss       Hanns                 NaN        NaN
# 213               von Sundgau       Hanns                 NaN        NaN
# 214                    Meiger    Heinrich                 NaN        NaN
# 215                 Villinger       Peter                 NaN        NaN
# 216         von Truchtersheim       Rülin                 NaN        NaN
# 217                    Welsch    Lienhart                 NaN        NaN
# 218                 Rosenberg       Cuntz                 NaN        NaN
# 219                  Lembelin       Claus                 NaN        NaN
# 220                    Omeder       Götze                 NaN        NaN
# 221                Erstenberg    Heinrich                 NaN        NaN
# 222                   Wideman       Hanns      [der Ratsherr]        NaN
# 223            Glockengiesser       Hanns                 NaN        NaN
# 224                Weisseisen       Hanns                 NaN        NaN
# 225                      Adam       Peter                 NaN        NaN
# 226                  Allewelt       Hanns                 NaN        NaN
# 227             am Vischmarkt     Ludeman                 NaN        NaN
# 228               von Belheim       Claus                 NaN        NaN
# 229               Stückgarter    Bechtolt                 NaN        NaN
# 230                     Hecht       Hanns                 NaN        NaN
# 231         von Heiligenstein     Richart                 NaN        NaN
# 232                    Stalle    Hanseman                 NaN        NaN
# 233                   Lötysen        Jost                 NaN        NaN
# 234                    Studel       Hanns      [der Ratsherr]        NaN
# 235                   Bintzel       Claus                 NaN        NaN
# 236                    Swartz      Jeckel                 NaN        NaN
# 237                       NaN      Veltin                 NaN        NaN
# 238                       NaN      Rudolf                 NaN        NaN
# 239           in Sankt Thoman     Walther      [der Ratsherr]        NaN
# 240                von Brumat       Peter                 NaN        NaN
# 241                 Wurtzgart         NaN                 NaN        NaN
# 242                 zum Sluch       Hanns                 NaN        NaN
# 243              von Molsheim       Hanns                 NaN        NaN
# 244                       NaN     Richart                 NaN        NaN
# 245           zu Sankt Stefan      Michel                 NaN        NaN
# 246                     Wolff       Jerge                 NaN        NaN
# 247                    Mosung       Hanns                 NaN        NaN
# 248          bei der Metzigen       Claus                 NaN        NaN
# 249          bei Sankt Martin    Heinrich                 NaN        NaN
# 250            am Pfennigturm      Andres                 NaN        NaN
# 251                     Flach      Oswalt                 NaN        NaN
# 252                     Rorer        Marx                 NaN        NaN
# 253                     Rorer       Peter                 NaN        NaN
# 254                     Wolff    Hanseman                 NaN        NaN
# 255            auf dem Graben     Cüntzel                 NaN        NaN
# 256            unter Kürsener      Andres                 NaN        NaN
# 257           von Lampertheim       Peter                 NaN        NaN
# 258           von Lampertheim      Ulrich      [der Ratsherr]        NaN
# 259           von Lampertheim       Claus                 NaN        NaN
# 260                     Kempf       Claus                 NaN        NaN
# 261             am Vischmarkt     Lentzel                 NaN        NaN
# 262                von Mentze       Cuntz                 NaN        NaN
# 263                  Gabehart         NaN                 NaN        NaN
# 264                Schaffener       Jerge                 NaN        NaN
# 265                   Hügeler    Bechtolt                 NaN        NaN
# 266                     Frünt       Claus                 NaN        NaN
# 267                     Knapp       Hanns                 NaN        NaN
# 268                     Pfowe       Hanns                 NaN        NaN
# 269                    Heiden       Cuntz      [der Ratsherr]        NaN
# 270                 Hasenoren    Bernhart                 NaN        NaN
# 271                    Bender     Obrecht                 NaN        NaN
# 272                  von Wile    Reimbolt                 NaN        NaN
# 273                  Reimbolt       Hanns                 NaN        NaN
# 274                  Usenberg       Heinz                 NaN        NaN
# 275                       NaN         NaN   [der Schultheiss]        NaN
# 276                      Smit       Claus                 NaN        NaN
# 277                    Stumpf       Adolf                 NaN        NaN
# 278                     Lehel    Burckart                 NaN        NaN
# 279                   Günther       Hanns                 NaN        NaN
# 280             Kum noch hint       Hanns                 NaN        NaN
# 281                von Wangen      Erhart                 NaN        NaN
# 282                Hennenberg       Hanns                 NaN        NaN
# 283                     Götze       Hanns                 NaN        NaN
# 284                     Flöss         NaN           [Meister]        NaN
# 285                    Pfaffe       Claus                 NaN        NaN
# 286                  Büttener      Laulin                 NaN        NaN
# 287                    Ulrich      Mathis                 NaN        NaN
# 288                    Röttel      Hensel                 NaN        NaN
# 289                   Diebolt       Hanns                 NaN        NaN
# 290                   Leheman       Hanns                 NaN        NaN
# 291                  Sundheim      Michel                 NaN        NaN
# 292                      Lamb       Hanns      [der Ratsherr]        NaN
# 293               Schertzheim       Jerge                 NaN        NaN
# 294                      Lamb    Bechtolt                 NaN        NaN
# 295                   Vachman       Claus                 NaN        NaN
# 296                    Munich    Dietrich                 NaN        NaN
# 297                   Luschen       Claus                 NaN        NaN
# 298                     Grave     Anshelm                 NaN        NaN
# 299                     Bentz      Laulin                 NaN        NaN
# 300                  Dreizehn       Jerge   [der Schultheiss]        NaN
# 301                   Gerbott       Peter      [der Ratsherr]        NaN
# 302                  Rinstett     Fritsch                 NaN        NaN
# 303                    Treger     Oberlin                 NaN        NaN
# 304                    Treger       Hanns                 NaN        NaN
# 305                  Reinhart       Hanns                 NaN        NaN
# 306             zur Neuenburg       Hanns                 NaN        NaN
# 307                 Liebekind     Oberlin                 NaN        NaN
# 308                 Sachsbach      Conrat                 NaN        NaN
# 309                     Claus       Hanns                 NaN        NaN
# 310                   Spilman       Hanns                 NaN        NaN
# 311                Fursenbach       Jacob                 NaN        NaN
# 312                    Kiebel    Hanseman                 NaN        NaN
# 313                     Spete       Hanns      [der Ratsherr]        NaN
# 314                     Clowe       Jacob                 NaN        NaN
# 315               Duntzenheim       Claus                 NaN        NaN
# 316                   Fleisch     Cüntzel                 NaN   der Alte
# 317                   Henckin       Hanns                 NaN        NaN
# 318                     Drens    Henselin                 NaN        NaN
# 319                     Peter       Hanns                 NaN        NaN
# 320                       NaN       Kurin                 NaN        NaN
# 321                       NaN         NaN                 NaN        NaN
# 322                     Hirte       Hanns                 NaN        NaN
# 323                     Ersam       Hanns                 NaN        NaN
# 324                   Kilwart       Hanns                 NaN  der Junge
# 325                       NaN      Mennel                 NaN        NaN
# 326                     Minne      Hensel                 NaN        NaN
# 327                     Künig       Claus      [der Ratsherr]        NaN
# 328                   Spiegel       Hanns                 NaN        NaN
# 329                    Renner     Diebolt                 NaN        NaN
# 330                      Koch       Hanns                 NaN   der Alte
# 331                      Koch       Hanns                 NaN  der Junge
# 332                  Girbaden       Hanns                 NaN        NaN
# 333                    Morung    Hanseman                 NaN        NaN
# 334                  von Wile       Hanns                 NaN        NaN
# 335                Wildersinn       Hanns                 NaN        NaN
# 336                 Hebenagel       Hanns                 NaN        NaN
# 337                 von Thann       Hanns                 NaN        NaN
# 338                  von Kork       Peter                 NaN        NaN
# 339          von Schlettstadt       Hanns                 NaN        NaN
# 340                    Lütold      Michel                 NaN        NaN
# 341                    Ripolt       Hanns      [der Ratsherr]        NaN
# 342                    Volmar     Fritsch                 NaN        NaN
# 343                    Volmar       Claus                 NaN        NaN
# 344                  Swencker       Hanns                 NaN        NaN
# 345                 Gottfried     Fritsch                 NaN        NaN
# 346                       NaN         Six                 NaN        NaN
# 347                    Herbst       Peter                 NaN        NaN
# 348                 Mittelhus      Veltin                 NaN        NaN
# 349                      Butz       Hanns                 NaN        NaN
# 350                    Kiebel      Ulrich                 NaN        NaN
# 351                    Porten       Hanns                 NaN        NaN
# 352              von Bergheim       Hanns                 NaN        NaN
# 353                  Weidlich      Ulrich      [der Schriber]        NaN
# 354                 von Gemer      Andres                 NaN        NaN
# 355              von Molsheim       Hanns                 NaN        NaN
# 356                     Ripel      Michel                 NaN   der Alte
# 357                     Ripel      Michel      [der Ratsherr]  der Junge
# 358             auf der Werde     Fritsch                 NaN        NaN
# 359                     Ripel    Bernhart                 NaN        NaN
# 360                   Graseck       Claus                 NaN        NaN
# 361                Winsticher     Gerhart                 NaN        NaN
# 362          von Geispolsheim     Wilhelm                 NaN        NaN
# 363                    Swartz      Conrat                 NaN        NaN
# 364              von Bergheim       Hanns                 NaN        NaN
# 365                      Walt       Hanns      [der Ratsherr]        NaN
# 366                 Ammeister         NaN           [Meister]        NaN
# 367                     Clein       Hanns      [der Kacheler]        NaN
# 368                Estericher       Peter                 NaN        NaN
# 369                    Ganser      Michel      [der Kacheler]        NaN
# 370                von Zabern      Syfrit                 NaN        NaN
# 371                      Smit       Hanns                 NaN        NaN
# 372                     Bösch   Friderich                 NaN        NaN
# 373                   Wernlin   Stoffelus                 NaN        NaN
# 374                       NaN   Friderich      [der Kacheler]        NaN
# 375             von Durningen       Sigel      [der Ratsherr]        NaN
# 376                    Paulus       Hanns                 NaN        NaN
# 377                      Hirt       Hanns                 NaN   der Alte
# 378                   Förster      Symont                 NaN        NaN

# %%
dataframe[["nom","prénom"]].describe()
# Out:
#                  nom prénom
# count            366    368
# unique           301     77
# top     von Molsheim  Hanns
# freq               5    104

# %%
df2 = dataframe["prénom"].value_counts()

# %%
import matplotlib.pyplot as plt
