# %% [markdown]
# # Importation des modules

# %%
import pandas as pd
from bs4 import BeautifulSoup
from ast import literal_eval
import csv
import re

# %% [markdown]
# # Importation des CSV de référence

# %%
RefNom = pd.read_csv("./../Tables/ReferentielNoms.csv",converters={"FormesNonNormalisées": literal_eval}).set_index("NomNormalisé")
RefPrenom = pd.read_csv("./../Tables/RéférentielPrénoms.csv", converters={"FormesNonNormalisées": literal_eval}).set_index("PrénomNormalisé")

# %% [markdown]
# # 1. Parsing du document xml et extraction des informations en vue de la constitution d'un dataframe

# %%
def ParsingXMLTEItoDictList(CheminRelatifFichier,DivCC):
    
    soup = BeautifulSoup(open(CheminRelatifFichier, 'r'))

    ListeDicosPersonnes = []
    
    for div in soup.find_all('div'):
            if div['type'] == 'date':
                Date = div['n']

    for persname in soup.find_all('persname'):

        DicoPersonne = {}
        
        # Loop pour nom non normalisé.
        for surname in persname.find_all('surname'):
            DicoPersonne['nomNN'] = surname.get_text()
            
        # Loop pour nom normalisé.
            DataToComp = surname.get_text()
            DataToComp = re.sub(r"\n", " ", DataToComp)
            if type(DataToComp) == float:
                DicoPersonne['nom'] = ''
            for j in range (0, len(RefNom.index)):
                CheckN = RefNom.iloc[j,1]
                for element in CheckN:
                    if DataToComp == element:
                        DicoPersonne['nom'] = RefNom.index[j]
        
        # Loop pour prénom non normalisé.
        for forename in persname.find_all('forename'):
            DicoPersonne['prénomNN'] = forename.get_text()
        
        # Loop pour prénom normalisé.
            DataToComp = forename.get_text()
            DataToComp = re.sub(r"\n", " ", DataToComp)
            if type(DataToComp) == float:
                DicoPersonne['prénom'] = ''
            for j in range (0, len(RefPrenom.index)):
                CheckN = RefPrenom.iloc[j,2]
                for element in CheckN:
                    if DataToComp == element:
                        DicoPersonne['prénom'] = RefPrenom.index[j]

        for genname in persname.find_all('genname'):
            DicoPersonne['surnom'] = genname.get_text()

        Roles = []
        for rolename in persname.find_all('rolename'):
            Role = rolename.get_text()
            RoleToAppend = Role + '-' + Date
            Roles.append(RoleToAppend)
            DicoPersonne['fonction'] = Roles

        for div in persname.find_parents('div'):
            
            if div['type'] == 'Ordre' :
                DicoPersonne['corps civique'] = div['n']
            
            if div['type'] == 'Corporation':
                DicoPersonne['Corporation'] = div['n']
                
            if div['type'] == 'Poele':
                DicoPersonne['Poêle'] = div['n']
        
        NomCompletNN =  persname.get_text()
        NomCompletNN = re.sub(r"\n", " ", NomCompletNN)
        DicoPersonne['NomCompletNN'] = NomCompletNN    

        ListeDicosPersonnes.append(DicoPersonne)

    return (ListeDicosPersonnes)

# %%
ListeDicosPersonnes = ParsingXMLTEItoDictList('../Sources/EditionsXML/aves_aa_195_f69r-77r-v2.xml', 'TEI')
print(ListeDicosPersonnes)
# Out:
# [{'nomNN': 'Schalck', 'nom': 'Schalk', 'prénomNN': 'Obreht', 'prénom': 'Obrecht', 'fonction': ['her-1444', 'ammeister-1444'], 'Poêle': 'Zum_Encker', 'Corporation': 'à_l_Ancre', 'corps civique': 'Échevinat', 'NomCompletNN': 'her Obreht Schalck der ammeister'}, {'nomNN': 'Armbruster In Brantgasse', 'nom': 'Armbruster in Brantgasse', 'prénomNN': 'Cünrat', 'prénom': 'Konrat', 'Poêle': 'Zum_Encker', 'Corporation': 'à_l_Ancre', 'corps civique': 'Échevinat', 'NomCompletNN': 'Cünrat Armbruster In Brantgasse'}, {'nomNN': 'Amlung', 'nom': 'Amelung', 'prénomNN': 'Hanns', 'prénom': 'Johann', 'Poêle': 'Zum_Encker', 'Corporation': 'à_l_Ancre', 'corps civique': 'Échevinat', 'NomCompletNN': 'Hanns Amlung'}, {'nomNN': 'Phige', 'nom': 'Phye', 'prénomNN': 'Reimbolt', 'prénom': 'Reimbolt', 'Poêle': 'Zum_Encker', 'Corporation': 'à_l_Ancre', 'corps civique': 'Échevinat', 'NomCompletNN': 'Reimbolt Phige'}, {'nomNN': 'Lumbart', 'nom': 'Lumbart', 'prénomNN': 'Hanns', 'prénom': 'Johann', 'Poêle': 'Zum_Encker', 'Corporation': 'à_l_Ancre', 'corps civique': 'Échevinat', 'NomCompletNN': 'Hanns Lumbart'}, {'nomNN': 'Lumbart', 'nom': 'Lumbart', 'prénomNN': 'Steffan', 'prénom': 'Stefan', 'Poêle': 'Zum_Encker', 'Corporation': 'à_l_Ancre', 'corps civique': 'Échevinat', 'NomCompletNN': 'Steffan Lumbart'}, {'nomNN': 'Armbruster', 'nom': 'Armbruster', 'prénomNN': 'Hanns', 'prénom': 'Johann', 'fonction': ['rotherre-1444'], 'Poêle': 'Zum_Encker', 'Corporation': 'à_l_Ancre', 'corps civique': 'Échevinat', 'NomCompletNN': 'Hanns Armbruster der rotherre'}, {'nomNN': 'Bisinger', 'nom': 'Bisinger', 'prénomNN': 'Heinrich', 'prénom': 'Heinrich', 'Poêle': 'Zum_Encker', 'Corporation': 'à_l_Ancre', 'corps civique': 'Échevinat', 'NomCompletNN': 'Heinrich Bisinger'}, {'nomNN': 'Wissenburg', 'nom': 'Wissenburg', 'prénomNN': 'Hanns', 'prénom': 'Johann', 'Poêle': 'Zum_Encker', 'Corporation': 'à_l_Ancre', 'corps civique': 'Échevinat', 'NomCompletNN': 'Hanns Wissenburg'}, {'nomNN': 'von Lutesheim', 'nom': 'Leutesheim, von', 'prénomNN': 'Hanns', 'prénom': 'Johann', 'Poêle': 'Zum_Encker', 'Corporation': 'à_l_Ancre', 'corps civique': 'Échevinat', 'NomCompletNN': 'Hanns von Lutesheim'}, {'nomNN': 'Hage', 'nom': 'Hage', 'prénomNN': 'Jacop', 'prénom': 'Jacob', 'Poêle': 'Zum_Encker', 'Corporation': 'à_l_Ancre', 'corps civique': 'Échevinat', 'NomCompletNN': 'Jacop Hage'}, {'nomNN': 'Merckel', 'nom': 'Merckel', 'prénomNN': 'Cüntzel', 'prénom': 'Küntz', 'Poêle': 'Zum_Encker', 'Corporation': 'à_l_Ancre', 'corps civique': 'Échevinat', 'NomCompletNN': 'Cüntzel Merckel'}, {'nomNN': 'Berner', 'nom': 'Berner', 'prénomNN': 'Frantz', 'prénom': 'Frantz', 'Poêle': 'Zum_Encker', 'Corporation': 'à_l_Ancre', 'corps civique': 'Échevinat', 'NomCompletNN': 'Frantz Berner'}, {'nomNN': 'Jude', 'nom': 'Jude', 'prénomNN': 'Heintz', 'prénom': 'Heintz', 'Poêle': 'Zum_Encker', 'Corporation': 'à_l_Ancre', 'corps civique': 'Échevinat', 'NomCompletNN': 'Heintz Jude'}, {'nomNN': 'Amlung', 'nom': 'Amelung', 'prénomNN': 'Jacob', 'prénom': 'Jacob', 'Poêle': 'Zum_Encker', 'Corporation': 'à_l_Ancre', 'corps civique': 'Échevinat', 'NomCompletNN': 'Jacob Amlung'}, {'fonction': ['zinsmeister-1444'], 'Poêle': 'Zum_Encker', 'Corporation': 'à_l_Ancre', 'corps civique': 'Échevinat', 'NomCompletNN': 'der zinsmeister'}, {'nomNN': 'Rebe', 'nom': 'Rebe', 'prénomNN': 'Laulin', 'prénom': 'Lauwel', 'Poêle': 'Zum_Schiff', 'Corporation': 'à_l_Ancre', 'corps civique': 'Échevinat', 'NomCompletNN': 'Laulin Rebe'}, {'nomNN': 'Schaffener', 'nom': 'Schaffner', 'prénomNN': 'Hanns', 'prénom': 'Johann', 'Poêle': 'Zum_Schiff', 'Corporation': 'à_l_Ancre', 'corps civique': 'Échevinat', 'NomCompletNN': 'Hanns Schaffener'}, {'nomNN': 'Schultheiss', 'nom': 'Schultheiss', 'prénomNN': 'Panteleon', 'prénom': 'Pantheleon', 'Poêle': 'Zum_Schiff', 'Corporation': 'à_l_Ancre', 'corps civique': 'Échevinat', 'NomCompletNN': 'Panteleon Schultheiss'}, {'nomNN': 'Erbe', 'nom': 'Erbe', 'prénomNN': 'Lawelin', 'prénom': 'Lauwel', 'Poêle': 'Zum_Schiff', 'Corporation': 'à_ ...

# %% [markdown]
# # 2. Normalisation des prénoms

# %%
DfListe = pd.DataFrame(ListeDicosPersonnes)
pd.set_option('display.max_rows', DfListe.shape[0]+1)
DfListe.fillna('NaN')
# Out:
#                         nomNN                       nom    prénomNN  \
# 0                     Schalck                    Schalk      Obreht
# 1    Armbruster In Brantgasse  Armbruster in Brantgasse      Cünrat
# 2                      Amlung                   Amelung       Hanns
# 3                       Phige                      Phye    Reimbolt
# 4                     Lumbart                   Lumbart       Hanns
# 5                     Lumbart                   Lumbart     Steffan
# 6                  Armbruster                Armbruster       Hanns
# 7                    Bisinger                  Bisinger    Heinrich
# 8                  Wissenburg                Wissenburg       Hanns
# 9               von Lutesheim           Leutesheim, von       Hanns
# 10                       Hage                      Hage       Jacop
# 11                    Merckel                   Merckel     Cüntzel
# 12                     Berner                    Berner      Frantz
# 13                       Jude                      Jude      Heintz
# 14                     Amlung                   Amelung       Jacob
# 15                        NaN                       NaN         NaN
# 16                       Rebe                      Rebe      Laulin
# 17                 Schaffener                 Schaffner       Hanns
# 18                Schultheiss               Schultheiss   Panteleon
# 19                       Erbe                      Erbe     Lawelin
# 20                        Reb                      Rebe      Hensel
# 21                        NaN                       NaN        Cüne
# 22                       Cüne                     Kühne      Hensel
# 23                       Lise                      Lise    Heinrich
# 24                       Wiss                     Weiss       Peter
# 25                    Diether                   Diether     Diebolt
# 26                      Jeger                     Jäger    Hanseman
# 27                      Hirse                     Hirse      Heintz
# 28                      Riffe                     Riffe        Adam
# 29                      Voltz                     Voltz       Peter
# 30                 Barpfennig                Barpfennig        Marx
# 31                 Barpfennig                Barpfennig     Rüdolff
# 32                    Brucker                   Brucker       Peter
# 33                      Riffe                     Riffe       Peter
# 34                  Hapmacher                 Hapmacher      Andres
# 35                Böschwiller               Böschwiller       Claus
# 36                     Slempe                  Schlempe    Heinrich
# 37                    Scholle                   Scholle    Bernhart
# 38              von Seckingen            Säckingen, von      Fridel
# 39                   Wormsser                   Wormser       Jacop
# 40                     Stange                    Stange      Erhart
# 41                     Stange                    Stange       Gilge
# 42                     Würant                    Würant       Claus
# 43                     Menser                   Mentzer       Hanns
# 44                  von Cölne                  Köln von       Peter
# 45                von Northus             Nordhuse, von       Hanns
# 46                       Arge                      Arge       Peter
# 47                  Ofentürer                 Ofentürer       Peter
# 48                 Dundenheim                Dundenheim       Hanns
# 49                 Dundenheim                Dundenheim       Peter
# 50                     Sahsse                    Sachse     Steffan
# 51                  von Marle           Marlenheim, von     Diebolt
# 52                   Vilinger                 Villinger      Erhart
# 53               Meistersheim              Meistersheim       Hanns
# 54                  Rotschilt                 Rotschilt     Wilhelm
# 55                  von Berse                Berse, von       Hanns
# 56                  von Berse                Berse, von      Conrat
# 57                  Betscholt                  Bechtolt     Wilhelm
# 58                 von Hasela               Haslach von      Mathis
# 59                   Wormsser                   Wormser       Voltz
# 60                       Kalt                      Kalt       Hanns
# 61                     Volmar                   Volkmar       Jacob
# 62                    Museler                   Müseler    Heinrich
# 63                  Offenburg                 Offenburg       Götze
# 64                    Behtolt                  Bechtolt       Hanns
# 65                   Lügerlin                  Lügerlin       Claus
# 66                 Dossenheim                Dossenheim         Hug
# 67                    Mesener                   Messner      Andres
# 68                   Ackenfüs                 Ackerfuss       Claus
# 69           von Truhtersheim        Trüchtersheim, von    Eberhart
# 70                  Bömgarter                Baumgarter      Erhart
# 71                     Brüder                    Bruder   Stoffelus
# 72                 Dossenheim                Dossenheim       Claus
# 73                    Stocker                   Stocker    Heinrich
# 74                  Bömgarter                Baumgarter       Claus
# 75         von Schaffoltzheim       Schaeffolsheim, von     Wilhelm
# 76            von Hirtingheim           Hürtigheim, von     Fritsch
# 77                 Armbruster                Armbruster      Conrat
# 78                      Lymer                    Leimer    Heinrich
# 79                     Renner                    Renner       Hanns
# 80                     Renner                    Renner       Hanns
# 81                von Belheim             Bellheim, von       Jacob
# 82                   Düringer                  Düringer        Cüne
# 83                   Düringer                  Düringer        Cüne
# 84                   Biderman                 Bidermann       Claus
# 85                von Wantzen              Wantzen, von       Jacob
# 86                 Odertzheim                Odertzheim       Hanns
# 87                  Steinbach                 Steinbach       Hanns
# 88                      Weber                     Weber       Claus
# 89                   von Rore                 Rohr, von       Claus
# 90               Franckenheim               Frankenheim      Ottman
# 91                 Kesselring                Kesselring       Hanns
# 92                   Melbrüge                  Melbrühe       Hanns
# 93                  von Nüfer               Nüffer, von      Berman
# 94                Kriegesheim                Kriegsheim       Claus
# 95                    Stumpff                    Stumpf       Hanns
# 96                   von Rore                 Rohr, von       Peter
# 97                     Günter                   Günther       Hanns
# 98                     Birböm                   Birbaum    Heinrich
# 99                     Griffe                    Griffe    Heinrich
# 100                Vendenheim                Vendenheim       Claus
# 101                  Metziger                  Metziger       Peter
# 102              Trachenfeils              Trachenfeils    Lienhart
# 103                   Smerwer                 Schmerwer      Andres
# 104               Saltzmütter               Saltzmütter  Dietherman
# 105              Trachenfeils              Trachenfeils       Hanns
# 106                Hitzvelder               Hirtzfelder       Hanns
# 107              Trachenfeils              Trachenfeils     Diebolt
# 108                  Willekin                  Willekin    Florentz
# 109                  Siferman                Siffermann    Burkhart
# 110                     Helle                     Helle      Veltin
# 111            von Crützenach          Kreutzenach, von       Hanns
# 112                   Leheman                   Lehmann    Heinrich
# 113           von Ernoltzheim          Ernoltzheim, von       Claus
# 114             Kannengiesser             Kannengiesser       Claus
# 115                       NaN                       NaN       Mertz
# 116                   Anshelm                   Anshelm       Jerge
# 117                 Missebach                 Missebach       Peter
# 118                  Newiller                 Neuwiller       Hanns
# 119                 Friburger                Freiburger       Jacob
# 120              von Sletstat         Schlettstadt, von       Hanns
# 121                     Arige                      Arge       Peter
# 122                Vegersheim                Fergesheim       Hanns
# 123                     Clein                     Klein       Hanns
# 124                      Lowe                      Löwe       Jacop
# 125                    Berner                    Berner       Peter
# 126                  Smalriem                Schmalriem      Andres
# 127                   Meister                   Meister       Hirtz
# 128                       Ott                       Ott       Hanns
# 129              von Sletstat         Schlettstadt, von       Hanns
# 130                    Snewel                  Schnebel    Heinrich
# 131                  Smalriem                Schmalriem      Adolff
# 132                 von Mentz                Mentz, von       Claus
# 133              von Molsheim             Molsheim, von       Hanns
# 134                    Glaser                    Glaser      Ülrich
# 135                     Ernst                     Ernst      Martin
# 136                    Glaser                    Glaser     Hertzog
# 137              von Altzheim             Altzheim, von       Hanns
# 138        von Geistpoltzheim        Geispoltzheim, von       Jacob
# 139                    Linser                    Linzer       Claus
# 140             von Ettenheim            Ettenheim, von      Mathis
# 141                 Hapmacher                 Hapmacher     Fritsch
# 142              von Molsheim             Molsheim, von        Adam
# 143                       Dür                      Dürr     Walther
# 144                    Sporer                    Sporer       Jacop
# 145           zü dem Tröschen             Tröschen, zum       Cüntz
# 146                    Sporer                    Sporer       Hanns
# 147                  Waldener                  Waldener       Jacob
# 148                    Franck                     Frank       Hanns
# 149                       NaN                       NaN       Gilge
# 150                Zür Hellen               Hellen, zür       Claus
# 151              von Hagenowe              Hagenau, von       Götze
# 152                 Wissensel                 Wissensel       Claus
# 153                    Spirer                    Spirer     Diebolt
# 154                    Spirer                    Spirer       Hanns
# 155                 von Jenff                 Genf, von       Hanns
# 156               von Erffürt               Erfurt, von     Niclaus
# 157                  Rosegart                  Rosegart    Heinrich
# 158              von Ehenheim             Ehenheim, von      Symont
# 159                       NaN                       NaN      Andres
# 160              von Ehenheim             Ehenheim, von      Veltin
# 161                 Westerman                Westermann      Martin
# 162                     Dolde                     Dolde    Lauwelin
# 163                  Schanlit                  Schanlit       Claus
# 164                    Vetter                    Vetter       Claus
# 165                 Bretteler                  Brettler       Hanns
# 166                Dingesheim                 Dingsheim       Hanns
# 167                Holtzhüser               Holtzhauser  Heintzeman
# 168                       NaN                       NaN     Wernlin
# 169                Güngesheim                 Gingsheim       Hanns
# 170                   Dalheim                  Dahlheim        Hans
# 171                 von Barre                Barre, von       Claus
# 172                     Selig                    Seelig       Peter
# 173                       NaN                       NaN   Martzolff
# 174                      Nefe                     Neffe       Hanns
# 175               Duntzenheim               Duntzenheim       Claus
# 176                    Bitsch                    Bitsch       Hanns
# 177                      Lore                      Lore       Hanns
# 178             von Isenhusen           Isenhausen, von      Erhart
# 179                     Lange                     Lange       Claus
# 180                  Kücheler                  Kücheler       Claus
# 181                    Mynner                    Minner       Hanns
# 182                Vendenheim                Vendenheim       Hanns
# 183                  von Sant                 Sant, von     Diebolt
# 184              von Molsheim             Molsheim, von       Peter
# 185                   Schenck                   Schenck       Hanns
# 186                       NaN                       NaN       Sitze
# 187                   Hafener                  Haffener       Jacob
# 188                     Seger                     Seger       Hanns
# 189                     Brant                     Brant     Diebolt
# 190             von Schuttern            Schuttern, von     Wilhelm
# 191                Sidenfaden               Seidenfaden      Fridel
# 192                  züm Rade                 Rade, zum    Bernhart
# 193              von Ütenheim            Uttenheim, von       Hanns
# 194                       NaN                       NaN       Peter
# 195                 von Worms                Worms, von      Alhelm
# 196                   Kipkorn                   Kipkorn       Hanns
# 197                     Zerig                     Zerig      Sifrit
# 198                   Rotgebe                   Rotgebe       Jacob
# 199                       NaN                       NaN    Monschin
# 200                    Zoller                    Zoller       Hanns
# 201                Eckendorff                 Eckendorf    Heinrich
# 202                    Arnolt                    Arnolt      Conrat
# 203               Schrotbanck               Schrotbanck      Conrat
# 204                  Leistman                 Leistmann    Dietrich
# 205             von Dürnyngen            Dürningen, von    Heinrich
# 206               Schrotbanck               Schrotbanck     Ortliep
# 207                von Lutern              Lautern, von       Hanns
# 208                 von Mentz                Mentz, von      Krafft
# 209                      Hüsz                      Hüss       Hanns
# 210              von Sungouwe              Sundgau, von       Hanns
# 211                    Meiger                    Meiger    Heinrich
# 212                  Vilinger                 Villinger       Peter
# 213          von Truhtersheim        Trüchtersheim, von        Rüle
# 214                     Welsh                    Welsch    Lienhart
# 215                 Rosenberg                 Rosenberg       Cüntz
# 216                  Lembelin                  Lembelin       Claus
# 217                    Omeder                   Ohmeter       Götze
# 218                Erstenberg                Erstenberg    Heinrich
# 219                   Wideman                 Weidemann       Hanns
# 220            Glockengiesser            Glockengiesser       Hanns
# 221                  Wiszysen                Weisseisen       Hanns
# 222                      Adam                      Adam       Peter
# 223                  Allewelt                  Allewelt       Hanns
# 224                       NaN                       NaN     Ludeman
# 225               von Belheim             Bellheim, von       Claus
# 226               Stückgarter               Stückgarter     Behtolt
# 227                   Hechede                   Heschde       Hanns
# 228         von Heiligenstein        Heiligenstein, von     Richart
# 229                    Stalle                    Stalle    Hanseman
# 230                   Lötysen                  Loteisen        Jost
# 231                    Stüdel                    Studel       Hanns
# 232                   Bintzel                   Bintzel       Claus
# 233                    Swartz                  Schwartz      Jeckel
# 234                       NaN                       NaN      Veltin
# 235                       NaN                       NaN     Rüdolff
# 236                       NaN                       NaN     Walther
# 237                von Brümat              Brümath, von       Peter
# 238                 Wurtzgart                 Wurtzgart         NaN
# 239                       NaN                       NaN       Hanns
# 240              von Molsheim             Molsheim, von       Hanns
# 241                       NaN                       NaN     Richart
# 242                       NaN                       NaN      Michel
# 243                     Wolff                      Wolf       Jörge
# 244                    Müsung                    Müsung       Hanns
# 245                       NaN                       NaN       Claus
# 246                       NaN                       NaN    Heinrich
# 247                       NaN                       NaN      Andres
# 248                     Flach                     Flach     Ohswalt
# 249                     Rorer                    Rohrer        Marx
# 250                     Rorer                    Rohrer       Peter
# 251                     Wolff                      Wolf    Hanseman
# 252                       NaN                       NaN      Üntzel
# 253                       NaN                       NaN      Andres
# 254           von Lampertheim          Lampertheim, von       Peter
# 255           von Lampertheim          Lampertheim, von      Ülrich
# 256           von Lampertheim          Lampertheim, von       Claus
# 257                    Kempff                     Kempf       Claus
# 258                       NaN                       NaN     Lentzel
# 259                von Mentze                Mentz, von       Cüntz
# 260                       NaN                       NaN    Gabehert
# 261                Schaffener                 Schaffner       Jerge
# 262                   Hügeler                   Hügeler     Behtolt
# 263                    Fründe                   Freunde       Claus
# 264                     Knapp                      Knap       Hanns
# 265                     Pfowe                     Pfaue       Hanns
# 266                    Heiden                     Heide      Cüntze
# 267                  Hasenore                  Hasenohr    Bernhart
# 268                    Bender                    Bender      Obreht
# 269                  von Wile                 Wile, von    Reimbolt
# 270                  Üsenberg                  Üsenberg      Heintz
# 271                       NaN                       NaN         NaN
# 272                      Smyt                   Schmied       Claus
# 273                    Stumpf                    Stumpf      Adolff
# 274                     Lehel                     Lehel    Burckart
# 275                   Günther                   Günther       Hanns
# 276             Kum noch Hint          Komm nach Hinten       Hanns
# 277                von Wangen               Wangen, von      Erhart
# 278                Hennenberg                Hennenberg       Hanns
# 279                     Götze                     Götze       Hanns
# 280                     Flösz                     Flöss         NaN
# 281                    Pfaffe                    Pfaffe       Claus
# 282                     Butte                     Butte      Laulin
# 283                    Ülrich                    Ülrich      Mathis
# 284                    Röttel                    Röttel      Hensel
# 285                   Diebolt                   Diebolt       Hanns
# 286                   Leheman                   Lehmann       Hanns
# 287                  Suntheim                  Sundheim      Michel
# 288                      Lamb                      Lamb       Hanns
# 289               Schertzheim               Schertzheim       Jerge
# 290                      Lamb                      Lamb     Behtolt
# 291                   Vachman                  Fachmann       Claus
# 292                    Münich                     Münch    Dietrich
# 293                    Lusche                    Lusche       Claus
# 294                     Grave                     Graff     Anshelm
# 295                    Bentze                     Bentz      Laulin
# 296                     Klige                     Klige       Hanns
# 297                  Hetteman                  Hettmann       Hanns
# 298                      Klie                     Klige       Cüntz
# 299                 Dritzehen                 Dreitzehn       Jerge
# 300                   Gerbott                   Gerboth       Peter
# 301                  Rinstett           Rheinstett, von     Fritsch
# 302                    Treger                    Träger     Oberlin
# 303                    Treger                    Träger       Hanns
# 304                  Reinhart                  Reinhart       Hanns
# 305                       NaN                       NaN       Hanns
# 306                 Liebekint                  Liebkint     Oberlin
# 307                  Sahsbach                  Sassbach      Conrat
# 308                     Claus                     Claus       Hanns
# 309                   Spilman                 Spielmann       Hanns
# 310                Fursenbach                Fürsenbach       Jacob
# 311                    Kiebel                    Kiebel    Hanseman
# 312                     Spete                    Spette       Hanns
# 313                     Clowe                     Claue       Jacob
# 314               Duntzenheim               Duntzenheim       Claus
# 315                   Fleisch                   Fleisch     Cüntzel
# 316                   Henckin                 Henneckin       Hanns
# 317                     Drens                     Drens    Henselin
# 318                     Peter                     Peter       Hanns
# 319                       NaN                       NaN       Kürin
# 320                  Lampreht                 Lamprecht       Peter
# 321                     Hirte                      Hirt       Hanns
# 322                     Ersam                    Ersame       Hanns
# 323                   Kilwart                   Kilwart       Hanns
# 324                       NaN                       NaN      Mennel
# 325                     Mynne                    Minner      Hensel
# 326                     Künig                     König       Claus
# 327                   Spiegel                   Spiegel       Hanns
# 328                    Renner                    Renner     Diebolt
# 329                      Koch                      Koch       Hanns
# 330                      Koch                      Koch       Hanns
# 331                  Girbaden                  Girbaden       Hanns
# 332                    Morung                    Morung    Hanseman
# 333                  von Wile                 Wile, von       Hanns
# 334                Wyldersynn                Wildersinn       Hanns
# 335                 Hebenagel                 Hebenagel       Hanns
# 336                  von Than                Thann, von       Hanns
# 337                 von Korck                Korck, von       Peter
# 338              von Sletstat         Schlettstadt, von       Hanns
# 339                    Michel                    Michel     Lütoltz
# 340                    Wipolt                    Wipolt       Hanns
# 341                    Volmar                   Volkmar     Fritsch
# 342                    Volmar                   Volkmar       Claus
# 343                  Swencker                Schwencker       Hanns
# 344                   Götfrit                 Gottfried     Fritsch
# 345                       NaN                       NaN         Six
# 346                   Herbest                    Herbst       Peter
# 347                 Mittelhus                Mittelhaus      Veltin
# 348                     Butze                     Butze       Hanns
# 349                    Kiebel                    Kiebel      Ülrich
# 350                     Porte                     Porte       Hanns
# 351              von Bergheim             Bergheim, von       Hanns
# 352                 Weidelich                  Weidlich      Ülrich
# 353                 von Gemer           Gemersheim, von      Andres
# 354              von Molsheim             Molsheim, von       Hanns
# 355                     Ripel                    Rippel      Michel
# 356                     Ripel                    Rippel      Michel
# 357                       NaN                       NaN     Fritsch
# 358                     Ripel                    Rippel    Bernhart
# 359                   Graseck                  Grasseck       Claus
# 360                Winsticher                Winsticher      Erhart
# 361         von Geispoltzheim        Geispoltzheim, von     Wilhelm
# 362                    Swartz                  Schwartz      Conrat
# 363             von Berckheim             Bergheim, von       Hanns
# 364                      Walt                      Walt       Hanns
# 365                 Ammeister                 Ammeister         NaN
# 366                Estericher              Österreicher       Claus
# 367                     Clein                     Klein       Hanns
# 368                Estericher              Österreicher       Peter
# 369                    Ganser                    Ganser      Michel
# 370                von Zabern               Zabern, von      Sifrit
# 371                     Smyde                   Schmied       Hanns
# 372                     Bösch                     Bösch   Friderich
# 373                   Wernlin                   Wernlin   Stoffelus
# 374                       NaN                       NaN   Friderich
# 375             von Dürnyngen            Dürningen, von       Sigel
# 376                    Paulus                    Paulus       Hanns
# 377                      Hirt                      Hirt       Hanns
# 378                   Förster                   Förster      Symont
#
#          prénom                                      fonction  \
# 0       Obrecht                    [her-1444, ammeister-1444]
# 1        Konrat                                           NaN
# 2        Johann                                           NaN
# 3      Reimbolt                                           NaN
# 4        Johann                                           NaN
# 5        Stefan                                           NaN
# 6        Johann                               [rotherre-1444]
# 7      Heinrich                                           NaN
# 8        Johann                                           NaN
# 9        Johann                                           NaN
# 10        Jacob                                           NaN
# 11        Küntz                                           NaN
# 12       Frantz                                           NaN
# 13       Heintz                                           NaN
# 14        Jacob                                           NaN
# 15          NaN                            [zinsmeister-1444]
# 16       Lauwel                                           NaN
# 17       Johann                                           NaN
# 18   Pantheleon                                           NaN
# 19       Lauwel                                           NaN
# 20       Hensel                                           NaN
# 21        Kühne                                           NaN
# 22       Hensel                                           NaN
# 23     Heinrich                                           NaN
# 24        Peter                                           NaN
# 25      Diebolt                                           NaN
# 26       Johann                                           NaN
# 27       Heintz                                           NaN
# 28         Adam  [her-1444, altammeister-1444, rotherre-1444]
# 29        Peter                                           NaN
# 30         Marx                                           NaN
# 31       Rüdolf                                           NaN
# 32        Peter                                           NaN
# 33        Peter                                           NaN
# 34       Andres                                           NaN
# 35        Claus                                           NaN
# 36     Heinrich                                           NaN
# 37     Bernhart                                           NaN
# 38    Friedrich                                           NaN
# 39        Jacob                                           NaN
# 40       Erhart                                           NaN
# 41        Gilge                                           NaN
# 42        Claus                                           NaN
# 43       Johann                                           NaN
# 44        Peter                                           NaN
# 45       Johann                                           NaN
# 46        Peter                                           NaN
# 47        Peter                                           NaN
# 48       Johann                                           NaN
# 49        Peter                                           NaN
# 50       Stefan                                           NaN
# 51      Diebolt                                           NaN
# 52       Erhart                                           NaN
# 53       Johann  [her-1444, altammeister-1444, rotherre-1444]
# 54      Wilhelm                                           NaN
# 55       Johann                                           NaN
# 56       Konrat                                           NaN
# 57      Wilhelm                                           NaN
# 58       Mathis                                           NaN
# 59        Völtz                                           NaN
# 60       Johann                                           NaN
# 61        Jacob                                           NaN
# 62     Heinrich                                           NaN
# 63        Götze                                           NaN
# 64       Johann                                           NaN
# 65        Claus                                           NaN
# 66          Hug                 [her-1444, altammeister-1444]
# 67       Andres                                           NaN
# 68        Claus                                           NaN
# 69     Eberhart                                           NaN
# 70       Erhart                                           NaN
# 71    Stoffelus                                           NaN
# 72        Claus                                           NaN
# 73     Heinrich                                           NaN
# 74        Claus                               [rotherre-1444]
# 75      Wilhelm                                           NaN
# 76      Fritsch                                           NaN
# 77       Konrat  [her-1444, altammeister-1444, rotherre-1444]
# 78     Heinrich                                           NaN
# 79       Johann                                           NaN
# 80       Johann                                           NaN
# 81        Jacob                                           NaN
# 82        Kühne                                           NaN
# 83        Kühne                                           NaN
# 84        Claus                                           NaN
# 85        Jacob                                           NaN
# 86       Johann                                           NaN
# 87       Johann                                           NaN
# 88        Claus                                           NaN
# 89        Claus                                           NaN
# 90       Ottman                                           NaN
# 91       Johann                                           NaN
# 92       Johann                                           NaN
# 93     Behrmann                                           NaN
# 94        Claus                                           NaN
# 95       Johann                               [rotherre-1444]
# 96        Peter                                           NaN
# 97       Johann                                           NaN
# 98     Heinrich                                           NaN
# 99     Heinrich                                           NaN
# 100       Claus                                           NaN
# 101       Peter                                           NaN
# 102    Lienhart                 [her-1444, altammeister-1444]
# 103      Andres                                           NaN
# 104    Dietrich                                           NaN
# 105      Johann                                           NaN
# 106      Johann                                           NaN
# 107     Diebolt                               [rotherre-1444]
# 108    Florentz                                           NaN
# 109    Burkhart                                           NaN
# 110      Veltin                                           NaN
# 111      Johann                                           NaN
# 112    Heinrich                                           NaN
# 113       Claus                                           NaN
# 114       Claus                                           NaN
# 115       Mertz                                           NaN
# 116       Jerge                                           NaN
# 117       Peter                                           NaN
# 118      Johann                                           NaN
# 119       Jacob                                           NaN
# 120      Johann                                           NaN
# 121       Peter                                           NaN
# 122      Johann                                           NaN
# 123      Johann                           [müntzmeister-1444]
# 124       Jacob                                           NaN
# 125       Peter                                           NaN
# 126      Andres                                           NaN
# 127       Hirtz                                           NaN
# 128      Johann                                           NaN
# 129      Johann                               [rotherre-1444]
# 130    Heinrich                                           NaN
# 131       Adolf                                           NaN
# 132       Claus                                           NaN
# 133      Johann                             [armbruster-1444]
# 134      Ülrich                                           NaN
# 135      Martin                                           NaN
# 136      Herzog                                           NaN
# 137      Johann                                           NaN
# 138       Jacob                 [her-1444, altammeister-1444]
# 139       Claus                               [rotherre-1444]
# 140      Mathis                                           NaN
# 141     Fritsch                                           NaN
# 142        Adam                                           NaN
# 143     Walther                                           NaN
# 144       Jacob                                           NaN
# 145       Küntz                                           NaN
# 146      Johann                                           NaN
# 147       Jacob                                           NaN
# 148      Johann                                           NaN
# 149       Gilge                                           NaN
# 150       Claus                               [rotherre-1444]
# 151       Götze                                           NaN
# 152       Claus                                           NaN
# 153     Diebolt                                           NaN
# 154      Johann                                           NaN
# 155      Johann                                           NaN
# 156       Claus                                           NaN
# 157    Heinrich                                           NaN
# 158      Symont                                           NaN
# 159      Andres                                           NaN
# 160      Veltin                                           NaN
# 161      Martin                                           NaN
# 162      Lauwel                                           NaN
# 163       Claus                 [her-1444, altammeister-1444]
# 164       Claus                                           NaN
# 165      Johann                                           NaN
# 166      Johann                                           NaN
# 167      Heintz                                           NaN
# 168     Wernher                                           NaN
# 169      Johann                                           NaN
# 170      Johann                                           NaN
# 171       Claus                                           NaN
# 172       Peter                                           NaN
# 173    Martzolf                                           NaN
# 174      Johann                                           NaN
# 175       Claus                               [rotherre-1444]
# 176      Johann                                           NaN
# 177      Johann                                           NaN
# 178      Erhart                                           NaN
# 179       Claus                                           NaN
# 180       Claus                                           NaN
# 181      Johann                                           NaN
# 182      Johann                                           NaN
# 183     Diebolt                                           NaN
# 184       Peter                                           NaN
# 185      Johann                                           NaN
# 186        Sixt                           [stallmeister-1444]
# 187       Jacob                          [kouffhusherre-1444]
# 188      Johann                               [rotherre-1444]
# 189     Diebolt                                           NaN
# 190     Wilhelm                                           NaN
# 191   Friedrich                                           NaN
# 192    Bernhart                                           NaN
# 193      Johann                                           NaN
# 194       Peter                                           NaN
# 195    Adalhelm                                           NaN
# 196      Johann                             [schaffener-1444]
# 197      Sifrit                               [rotherre-1444]
# 198       Jacob                                           NaN
# 199   Monschein                                           NaN
# 200      Johann                                           NaN
# 201    Heinrich                                           NaN
# 202      Konrat                                           NaN
# 203      Konrat                                           NaN
# 204    Dietrich                                           NaN
# 205    Heinrich                                           NaN
# 206     Ortlieb                                           NaN
# 207      Johann                                           NaN
# 208       Kraft                                           NaN
# 209      Johann                                           NaN
# 210      Johann                                           NaN
# 211    Heinrich                                           NaN
# 212       Peter                                           NaN
# 213    Ruhlmann                                           NaN
# 214    Lienhart                                           NaN
# 215       Küntz                                           NaN
# 216       Claus                                           NaN
# 217       Götze                                           NaN
# 218    Heinrich                                           NaN
# 219      Johann                               [rotherre-1444]
# 220      Johann                                           NaN
# 221      Johann                                           NaN
# 222       Peter                                           NaN
# 223      Johann                                           NaN
# 224      Ludwig                                           NaN
# 225       Claus                                           NaN
# 226    Bechtolt                                           NaN
# 227      Johann                                           NaN
# 228     Richart                                           NaN
# 229      Johann                                           NaN
# 230        Jost                                           NaN
# 231      Johann                               [rotherre-1444]
# 232       Claus                                           NaN
# 233      Jeckel                                           NaN
# 234      Veltin                                           NaN
# 235      Rüdolf                                           NaN
# 236     Walther                               [rotherre-1444]
# 237       Peter                                           NaN
# 238         NaN                                           NaN
# 239      Johann                                           NaN
# 240      Johann                                           NaN
# 241     Richart                                           NaN
# 242      Michel                                           NaN
# 243       Jerge                                           NaN
# 244      Johann                                           NaN
# 245       Claus                                           NaN
# 246    Heinrich                                           NaN
# 247      Andres                                           NaN
# 248      Oswalt                                           NaN
# 249        Marx                                           NaN
# 250       Peter                                           NaN
# 251      Johann                                           NaN
# 252      Üntzel                                           NaN
# 253      Andres                                           NaN
# 254       Peter                                           NaN
# 255      Ülrich                                           NaN
# 256       Claus                                           NaN
# 257       Claus                                           NaN
# 258       Lentz                                           NaN
# 259       Küntz                                           NaN
# 260     Gebhart                                           NaN
# 261       Jerge                                           NaN
# 262    Bechtolt                                           NaN
# 263       Claus                                           NaN
# 264      Johann                                           NaN
# 265      Johann                                           NaN
# 266       Küntz                               [rotherre-1444]
# 267    Bernhart                                           NaN
# 268     Obrecht                                           NaN
# 269    Reimbolt                                           NaN
# 270      Heintz                                           NaN
# 271         NaN                            [schultheiss-1444]
# 272       Claus                                           NaN
# 273       Adolf                                           NaN
# 274    Burkhart                                           NaN
# 275      Johann                                           NaN
# 276      Johann                                           NaN
# 277      Erhart                                           NaN
# 278      Johann                                           NaN
# 279      Johann                                           NaN
# 280         NaN                                [meister-1444]
# 281       Claus                                           NaN
# 282      Lauwel                                           NaN
# 283      Mathis                                           NaN
# 284      Hensel                                           NaN
# 285      Johann                                           NaN
# 286      Johann                                           NaN
# 287      Michel                                           NaN
# 288      Johann                               [rotherre-1444]
# 289       Jerge                                           NaN
# 290    Bechtolt                                           NaN
# 291       Claus                                           NaN
# 292    Dietrich                                           NaN
# 293       Claus                                           NaN
# 294     Anshelm                                           NaN
# 295      Lauwel                                           NaN
# 296      Johann                               [rotherre-1444]
# 297      Johann                                           NaN
# 298       Küntz                                           NaN
# 299       Jerge                           [schultheisse-1444]
# 300       Peter                               [rotherre-1444]
# 301     Fritsch                                           NaN
# 302     Oberlin                                           NaN
# 303      Johann                                           NaN
# 304      Johann                                           NaN
# 305      Johann                                           NaN
# 306     Oberlin                                           NaN
# 307      Konrat                                           NaN
# 308      Johann                                           NaN
# 309      Johann                                           NaN
# 310       Jacob                                           NaN
# 311      Johann                                           NaN
# 312      Johann                               [rotherre-1444]
# 313       Jacob                                           NaN
# 314       Claus                                           NaN
# 315       Küntz                                           NaN
# 316      Johann                                           NaN
# 317      Hensel                                           NaN
# 318      Johann                                           NaN
# 319       Kürin                                           NaN
# 320       Peter                                           NaN
# 321      Johann                                           NaN
# ...
# 247     Échevinat                              Andres am Pfennigturn
# 248     Échevinat                                      Ohswalt Flach
# 249     Échevinat                                         Marx Rorer
# 250     Échevinat                                        Peter Rorer
# 251     Échevinat                                     Hanseman Wolff
# 252     Échevinat                              Üntzel uff dem Graben
# 253     Échevinat                             Andres under Kürsenern
# 254     Échevinat                              Peter von Lampertheim
# 255     Échevinat                             Ülrich von Lampertheim
# 256     Échevinat                              Claus von Lampertheim
# 257     Échevinat                                       Claus Kempff
# 258     Échevinat                            Lentzel am Vischmercket
# 259     Échevinat                                   Cüntz von Mentze
# 260     Échevinat                                           Gabehert
# 261     Échevinat                                   Jerge Schaffener
# 262     Échevinat                                    Behtolt Hügeler
# 263     Échevinat                                       Claus Fründe
# 264     Échevinat                                        Hanns Knapp
# 265     Échevinat                                        Hanns Pfowe
# 266     Échevinat                         Cüntze Heiden der rotherre
# 267     Échevinat                                  Bernhart Hasenore
# 268     Échevinat                                      Obreht Bender
# 269     Échevinat                                  Reimbolt von Wile
# 270     Échevinat                                    Heintz Üsenberg
# 271     Échevinat                       der schultheiss von Molsheim
# 272     Échevinat                                         Claus Smyt
# 273     Échevinat                                      Adolff Stumpf
# 274     Échevinat                                     Burckart Lehel
# 275     Échevinat                                      Hanns Günther
# 276     Échevinat                                Hanns Kum noch Hint
# 277     Échevinat                                  Erhart von Wangen
# 278     Échevinat                                   Hanns Hennenberg
# 279     Échevinat                                        Hanns Götze
# 280     Échevinat                                      meister Flösz
# 281     Échevinat                                       Claus Pfaffe
# 282     Échevinat                                       Laulin Butte
# 283     Échevinat                                      Mathis Ülrich
# 284     Échevinat                                      Hensel Röttel
# 285     Échevinat                                      Hanns Diebolt
# 286     Échevinat                                      Hanns Leheman
# 287     Échevinat                                    Michel Suntheim
# 288     Échevinat                            Hanns Lamb der rotherre
# 289     Échevinat                                  Jerge Schertzheim
# 290     Échevinat                                       Behtolt Lamb
# 291     Échevinat                                      Claus Vachman
# 292     Échevinat                                    Dietrich Münich
# 293     Échevinat                                       Claus Lusche
# 294     Échevinat                                      Anshelm Grave
# 295     Échevinat                                      Laulin Bentze
# 296     Échevinat                           Hanns Klige der rotherre
# 297     Échevinat                                     Hanns Hetteman
# 298     Échevinat                                         Cüntz Klie
# 299     Échevinat                   Jerge Dritzehen der schultheisse
# 300     Échevinat                         Peter Gerbott der rotherre
# 301     Échevinat                                   Fritsch Rinstett
# 302     Échevinat                                     Oberlin Treger
# 303     Échevinat                                       Hanns Treger
# 304     Échevinat                                     Hanns Reinhart
# 305     Échevinat                               Hanns zür Nuwenbürge
# 306     Échevinat                                  Oberlin Liebekint
# 307     Échevinat                                    Conrat Sahsbach
# 308     Échevinat                                        Hanns Claus
# 309     Échevinat                                      Hanns Spilman
# 310     Échevinat                                   Jacob Fursenbach
# 311     Échevinat                                    Hanseman Kiebel
# 312     Échevinat                           Hanns Spete der rotherre
# 313     Échevinat                                        Jacob Clowe
# 314     Échevinat                                  Claus Duntzenheim
# 315     Échevinat                           Cüntzel Fleisch der alte
# 316     Échevinat                                      Hanns Henckin
# 317     Échevinat                                     Henselin Drens
# 318     Échevinat                                        Hanns Peter
# 319     Échevinat                                              Kürin
# 320     Échevinat                                     Peter Lampreht
# 321     Échevinat                                        Hanns Hirte
# 322     Échevinat                                        Hanns Ersam
# 323     Échevinat                            Hanns Kilwart der junge
# 324     Échevinat                                             Mennel
# 325     Échevinat                                       Hensel Mynne
# 326     Échevinat                           Claus Künig der rotherre
# 327     Échevinat                                      Hanns Spiegel
# 328     Échevinat                                     Diebolt Renner
# 329     Échevinat                                Hanns Koch der alte
# 330     Échevinat                               Hanns Koch der junge
# 331     Échevinat                                     Hanns Girbaden
# 332     Échevinat                                    Hanseman Morung
# 333     Échevinat                                     Hanns von Wile
# 334     Échevinat                                   Hanns Wyldersynn
# 335     Échevinat                                    Hanns Hebenagel
# 336     Échevinat                                     Hanns von Than
# 337     Échevinat                                    Peter von Korck
# 338     Échevinat                                 Hanns von Sletstat
# 339     Échevinat                                     Lütoltz Michel
# 340     Échevinat                          Hanns Wipolt der rotherre
# 341     Échevinat                                     Fritsch Volmar
# 342     Échevinat                                       Claus Volmar
# 343     Échevinat                                     Hanns Swencker
# 344     Échevinat                                    Fritsch Götfrit
# 345     Échevinat                                                Six
# 346     Échevinat                                      Peter Herbest
# 347     Échevinat                                   Veltin Mittelhus
# 348     Échevinat                                        Hanns Butze
# 349     Échevinat                                      Ülrich Kiebel
# 350     Échevinat                                        Hanns Porte
# 351     Échevinat                                 Hanns von Bergheim
# 352     Échevinat                     Ülrich Weidelich der schreiber
# 353     Échevinat                                   Andres von Gemer
# 354     Échevinat                                 Hanns von Molsheim
# 355     Échevinat                              Michel Ripel der alte
# 356     Échevinat                Michel Ripel der junge der rotherre
# 357     Échevinat                              Fritsch uff dem Werde
# 358     Échevinat                                     Bernhart Ripel
# 359     Échevinat                                      Claus Graseck
# 360     Échevinat                                  Erhart Winsticher
# 361     Échevinat                          Wilhelm von Geispoltzheim
# 362     Échevinat                                      Conrat Swartz
# 363     Échevinat                                Hanns von Berckheim
# 364     Échevinat                            Hanns Walt der rotherre
# 365     Échevinat                                  meister Ammeister
# 366     Échevinat                                   Claus Estericher
# 367     Échevinat                           Hanns Clein der kacheler
# 368     Échevinat                                   Peter Estericher
# 369     Échevinat                         Michel Ganser der kacheler
# 370     Échevinat                                  Sifrit von Zabern
# 371     Échevinat                                        Hanns Smyde
# 372     Échevinat                                    Friderich Bösch
# 373     Échevinat                                  Stoffelus Wernlin
# 374     Échevinat                             Friderich der kacheler
# 375     Échevinat                   Sigel von Dürnyngen der rotherre
# 376     Échevinat                                       Hanns Paulus
# 377     Échevinat                                Hanns Hirt der alte
# 378     Échevinat                                     Symont Förster
#
#         surnom
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29    der alte
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# 39         NaN
# 40         NaN
# 41         NaN
# 42         NaN
# 43         NaN
# 44         NaN
# 45         NaN
# 46         NaN
# 47         NaN
# 48         NaN
# 49         NaN
# 50         NaN
# 51         NaN
# 52         NaN
# 53         NaN
# 54         NaN
# 55         NaN
# 56         NaN
# 57         NaN
# 58         NaN
# 59         NaN
# 60         NaN
# 61         NaN
# 62         NaN
# 63         NaN
# 64         NaN
# 65         NaN
# 66         NaN
# 67         NaN
# 68         NaN
# 69         NaN
# 70         NaN
# 71         NaN
# 72         NaN
# 73         NaN
# 74         NaN
# 75         NaN
# 76         NaN
# 77         NaN
# 78         NaN
# 79    der alte
# 80   der junge
# 81         NaN
# 82    der alte
# 83   der junge
# 84         NaN
# 85         NaN
# 86         NaN
# 87         NaN
# 88         NaN
# 89         NaN
# 90         NaN
# 91         NaN
# 92         NaN
# 93         NaN
# 94         NaN
# 95         NaN
# 96         NaN
# 97         NaN
# 98         NaN
# 99         NaN
# 100        NaN
# 101        NaN
# 102        NaN
# 103        NaN
# 104        NaN
# 105        NaN
# 106        NaN
# 107        NaN
# 108        NaN
# 109        NaN
# 110        NaN
# 111        NaN
# 112        NaN
# 113        NaN
# 114        NaN
# 115        NaN
# 116        NaN
# 117        NaN
# 118        NaN
# 119        NaN
# 120        NaN
# 121        NaN
# 122        NaN
# 123        NaN
# 124        NaN
# 125        NaN
# 126        NaN
# 127        NaN
# 128        NaN
# 129        NaN
# 130        NaN
# 131        NaN
# 132        NaN
# 133        NaN
# 134        NaN
# 135        NaN
# 136        NaN
# 137        NaN
# 138        NaN
# 139        NaN
# 140        NaN
# 141        NaN
# 142        NaN
# 143        NaN
# 144        NaN
# 145        NaN
# 146        NaN
# 147        NaN
# 148        NaN
# 149        NaN
# 150        NaN
# 151        NaN
# 152        NaN
# 153        NaN
# 154        NaN
# 155        NaN
# 156        NaN
# 157        NaN
# 158        NaN
# 159        NaN
# 160        NaN
# 161        NaN
# 162        NaN
# 163        NaN
# 164        NaN
# 165        NaN
# 166        NaN
# 167        NaN
# 168        NaN
# 169        NaN
# 170        NaN
# 171        NaN
# 172        NaN
# 173        NaN
# 174        NaN
# 175        NaN
# 176        NaN
# 177        NaN
# 178        NaN
# 179        NaN
# 180        NaN
# 181        NaN
# 182        NaN
# 183        NaN
# 184        NaN
# 185   der alte
# 186        NaN
# 187        NaN
# 188        NaN
# 189        NaN
# 190        NaN
# 191        NaN
# 192        NaN
# 193        NaN
# 194        NaN
# 195        NaN
# 196        NaN
# 197        NaN
# 198        NaN
# 199        NaN
# 200        NaN
# 201        NaN
# 202        NaN
# 203        NaN
# 204        NaN
# 205        NaN
# 206        NaN
# 207        NaN
# 208        NaN
# 209        NaN
# 210        NaN
# 211        NaN
# 212        NaN
# 213        NaN
# 214        NaN
# 215        NaN
# 216        NaN
# 217        NaN
# 218        NaN
# 219        NaN
# 220        NaN
# 221        NaN
# 222        NaN
# 223        NaN
# 224        NaN
# 225        NaN
# 226        NaN
# 227        NaN
# 228        NaN
# 229        NaN
# 230        NaN
# 231        NaN
# 232        NaN
# 233        NaN
# 234        NaN
# 235        NaN
# 236        NaN
# 237        NaN
# 238        NaN
# 239        NaN
# 240        NaN
# 241        NaN
# 242        NaN
# 243        NaN
# 244        NaN
# 245        NaN
# 246        NaN
# 247        NaN
# 248        NaN
# 249        NaN
# 250        NaN
# 251        NaN
# 252        NaN
# 253        NaN
# 254        NaN
# 255        NaN
# 256        NaN
# 257        NaN
# 258        NaN
# 259        NaN
# 260        NaN
# 261        NaN
# 262        NaN
# 263        NaN
# 264        NaN
# 265        NaN
# 266        NaN
# 267        NaN
# 268        NaN
# 269        NaN
# 270        NaN
# 271        NaN
# 272        NaN
# 273        NaN
# 274        NaN
# 275        NaN
# 276        NaN
# 277        NaN
# 278        NaN
# 279        NaN
# 280        NaN
# 281        NaN
# 282        NaN
# 283        NaN
# 284        NaN
# 285        NaN
# 286        NaN
# 287        NaN
# 288        NaN
# 289        NaN
# 290        NaN
# 291        NaN
# 292        NaN
# 293        NaN
# 294        NaN
# 295        NaN
# 296        NaN
# 297        NaN
# 298        NaN
# 299        NaN
# 300        NaN
# 301        NaN
# 302        NaN
# 303        NaN
# 304        NaN
# 305        NaN
# 306        NaN
# 307        NaN
# 308        NaN
# 309        NaN
# 310        NaN
# 311        NaN
# 312        NaN
# 313        NaN
# 314        NaN
# 315   der alte
# 316        NaN
# 317        NaN
# 318        NaN
# 319        NaN
# 320        NaN
# 321        NaN
# 322        NaN
# 323  der junge
# 324        NaN
# 325        NaN
# 326        NaN
# 327        NaN
# 328        NaN
# 329   der alte
# 330  der junge
# 331        NaN
# 332        NaN
# 333        NaN
# 334        NaN
# 335        NaN
# 336        NaN
# 337        NaN
# 338        NaN
# 339        NaN
# 340        NaN
# 341        NaN
# 342        NaN
# 343        NaN
# 344        NaN
# 345        NaN
# 346        NaN
# 347        NaN
# 348        NaN
# 349        NaN
# 350        NaN
# 351        NaN
# 352        NaN
# 353        NaN
# 354        NaN
# 355   der alte
# 356  der junge
# 357        NaN
# 358        NaN
# 359        NaN
# 360        NaN
# 361        NaN
# 362        NaN
# 363        NaN
# 364        NaN
# 365        NaN
# 366        NaN
# 367        NaN
# 368        NaN
# 369        NaN
# 370        NaN
# 371        NaN
# 372        NaN
# 373        NaN
# 374        NaN
# 375        NaN
# 376        NaN
# 377   der alte
# 378        NaN

# %%
RefPrenom = pd.read_csv("./../Tables/RéférentielPrénoms.csv", converters={"FormesNonNormalisées": literal_eval}).set_index("PrénomNormalisé")

# %%
RefPrenom
# Out:
#                 PrénomFrançais                                Types  \
# PrénomNormalisé
# Adalhelm              Alleaume               ['masc', 'germanique']
# Adam                      Adam                ['masc', 'hébraïque']
# Adolf                  Adolphe               ['masc', 'germanique']
# Andres                   André                     ['masc', 'grec']
# Anshelm                Anselme               ['masc', 'germanique']
# Behrmann                   NaN               ['masc', 'germanique']
# Bechtolt               Bertold               ['masc', 'germanique']
# Bernhart               Bernard               ['masc', 'germanique']
# Burkhart                   NaN               ['masc', 'germanique']
# Claus                  Nicolas                     ['masc', 'grec']
# Diebolt              Thiebault               ['masc', 'germanique']
# Dietrich               Thierry                    ['masc', 'franc']
# Eberhart              Éberhard               ['masc', 'germanique']
# Erhart                     NaN               ['masc', 'germanique']
# Florentz               Florent                    ['masc', 'latin']
# Frantz                François               ['masc', 'germanique']
# Friedrich             Frédéric               ['masc', 'germanique']
# Fritsch              Friedrich  ['masc', 'germanique', 'diminutif']
# Gebhart                    NaN               ['masc', 'germanique']
# Gilge                   Gilles                     ['masc', 'grec']
# Götze                Gottfried  ['masc', 'germanique', 'diminutif']
# Heinrich                 Henri               ['masc', 'germanique']
# Heintz                   Henri  ['masc', 'germanique', 'diminutif']
# Hensel                    Jean  ['masc', 'germanique', 'diminutif']
# Herzog                     NaN               ['masc', 'germanique']
# Hirtz                      NaN               ['masc', 'germanique']
# Hug                     Hugues               ['masc', 'germanique']
# Jacob                    Jacob                ['masc', 'hébraïque']
# Jeckel                 Jacques                  ['masc', 'hébreux']
# Jerge                  Georges                     ['masc', 'grec']
# Johann                    Jean                ['masc', 'hébraïque']
# Jost                     Juste                    ['masc', 'latin']
# Konrat                  Konrad               ['masc', 'germanique']
# Kraft                      NaN               ['masc', 'germanique']
# Kühne                      NaN               ['masc', 'germanique']
# Küntz                   Konrad  ['masc', 'germanique', 'diminutif']
# Kürin                      NaN               ['masc', 'germanique']
# Lauwel                 Nicolas       ['masc', 'latin', 'diminutif']
# Lentz                  Laurent                    ['masc', 'latin']
# Lienhart               Léonard               ['masc', 'germanique']
# Ludwig                   Louis               ['masc', 'germanique']
# Lütholt                Léopold               ['masc', 'germanique']
# Martin                  Martin                    ['masc', 'latin']
# Martzolf                Marcel                    ['masc', 'latin']
# Marx                      Marc                    ['masc', 'latin']
# Mathis                  Mathis                ['masc', 'hébraïque']
# Männel                     NaN  ['masc', 'germanique', 'diminutif']
# Mertz                      NaN               ['masc', 'germanique']
# Michel                  Michel                ['masc', 'hébraïque']
# Monschein                  NaN               ['masc', 'germanique']
# Oberlin                    NaN               ['masc', 'germanique']
# Obrecht                 Albert               ['masc', 'germanique']
# Oswalt                  Oswald               ['masc', 'germanique']
# Ortlieb                    NaN               ['masc', 'germanique']
# Ottman                Ottfried               ['masc', 'germanique']
# Pantheleon           Pantéléon                     ['masc', 'grec']
# Peter                   Pierre                     ['masc', 'grec']
# Reimbolt              Rimbault               ['masc', 'germanique']
# Richart                Richard               ['masc', 'germanique']
# Rüdolf                Rodolphe               ['masc', 'germanique']
# Ruhlmann              Rodolphe  ['masc', 'germanique', 'diminutif']
# Siegel                   Sigel               ['masc', 'germanique']
# Sifrit               Siegfried               ['masc', 'germanique']
# Sixt                     Sixte                    ['masc', 'latin']
# Stefan                Stéphane                     ['masc', 'grec']
# Stoffelus           Christophe                     ['masc', 'grec']
# Symont                   Simon                ['masc', 'hébraïque']
# Ülrich                  Ulrich               ['masc', 'germanique']
# Üntzel                     NaN               ['masc', 'germanique']
# Veltin                Valentin                    ['masc', 'latin']
# Völtz                  Volkmar  ['masc', 'germanique', 'diminutif']
# Walther                Walther               ['masc', 'germanique']
# Wernher                 Werner               ['masc', 'germanique']
# Wilhelm              Guillaume               ['masc', 'germanique']
#
#                                               FormesNonNormalisées
# PrénomNormalisé
# Adalhelm                              [Adalhelm, Adelhelm, Alhelm]
# Adam                                                        [Adam]
# Adolf                                              [Adolf, Adolff]
# Andres                                                    [Andres]
# Anshelm                                                  [Anshelm]
# Behrmann                      [Behrmann, Behrman, Bermann, Berman]
# Bechtolt                                       [Behtolt, Bechtolt]
# Bernhart                                      [Bernhart, Bernhard]
# Burkhart         [Burkhart, Burkhard, Burckhart, Burckhard, Bur...
# Claus                             [Claus, Clauwes, Claws, Niclaus]
# Diebolt                       [Diebolt, Diebold, Tiebolt, Tiebold]
# Dietrich           [Dietrich, Diethermann, Dietherman, Dietherich]
# Eberhart                                      [Eberhart, Eberhard]
# Erhart                                            [Erhart, Erhard]
# Florentz                                       [Florentz, Florenz]
# Frantz                                             [Frantz, Franz]
# Friedrich        [Friedrich, Fridrich, Fridel, Friedel, Friderich]
# Fritsch                                                  [Fritsch]
# Gebhart                                                 [Gabehert]
# Gilge                                                [Gilge, Gilg]
# Götze                                       [Götze, Goetze, Gotze]
# Heinrich                                                [Heinrich]
# Heintz                                 [Heintz, Heinz, Heintzeman]
# Hensel                                          [Hensel, Henselin]
# Herzog                                           [Herzog, Hertzog]
# Hirtz                                                      [Hirtz]
# Hug                                                          [Hug]
# Jacob                                 [Jacob, Jacop, Jakob, Jakop]
# Jeckel                                                    [Jeckel]
# Jerge                                               [Jerge, Jörge]
# Johann           [Johann, Johan, Johanns, Johans, Hanns, Hans, ...
# Jost                                                        [Jost]
# Konrat           [Konrad, Konradt, Konrat, Cünrat, Cünrad, Conr...
# Kraft                                       [Kraft, Krafft, Craft]
# Kühne                                          [Kühne, Küne, Cüne]
# Küntz            [Küntz, Cüntz, Cüntzel, Cuentz, Cuentzel, Cünt...
# Kürin                                                      [Kürin]
# Lauwel                  [Lauwel, Lauwelin, Lawel, Lawelin, Laulin]
# Lentz                                                    [Lentzel]
# Lienhart                  [Lienhart, Lienhard, Leonhart, Leonhard]
# Ludwig                                           [Ludwig, Ludeman]
# Lütholt                [Lütholt, Lüthold, Lütolt, Lütold, Lütoltz]
# Martin                                                    [Martin]
# Martzolf                  [Martzolf, Martzolff, Marzolf, Marzolff]
# Marx                                                        [Marx]
# Mathis                                                    [Mathis]
# Männel                                                    [Mennel]
# Mertz                                                      [Mertz]
# Michel                                                    [Michel]
# Monschein                                    [Monschein, Monschin]
# Oberlin                                                  [Oberlin]
# Obrecht                                          [Obrecht, Obreht]
# Oswalt                                           [Ohswalt, Oswalt]
# Ortlieb                          [Ortlieb, Ortliep, Örtel, Oertel]
# Ottman                          [Ottman, Ottfried, Otman, Otfried]
# Pantheleon                                 [Pantheleon, Panteleon]
# Peter                                                      [Peter]
# Reimbolt                  [Reimbolt, Reimbold, Reinbolt, Reinbold]
# Richart                                         [Richart, Richard]
# Rüdolf                          [Rüdolf, Rüdolff, Rudolf, Rudolff]
# Ruhlmann                                                    [Rüle]
# Siegel                                             [Siegel, Sigel]
# Sifrit                                            [Sifrit, Syfrit]
# Sixt                                            [Sixt, Six, Sitze]
# Stefan                                           [Stefan, Steffan]
# Stoffelus        [Stoffelus, Stofelus, Stoffels, Stöffelus, Stö...
# Symont                            [Symont, Symond, Simont, Simond]
# Ülrich                 [Ülrich, Ulrich, Uelrich, Uolrich, Ualrich]
# Üntzel                                                    [Üntzel]
# Veltin                                                    [Veltin]
# Völtz                                   [Voltz, Völtz, Volz, Völz]
# Walther                                                  [Walther]
# Wernher                                 [Wernher, Werner, Wernlin]
# Wilhelm                                                  [Wilhelm]

# %%
'''
ListeNNN = []
ListeNNP = []
for i in range (0,len(DfListe.index)):
    DataToComp = DfListe.iloc[i,1]
    if type(DataToComp) == float:
        ListeNNP.append('') 
    for j in range (0, len(RefPrenom.index)):
        CheckN = RefPrenom.iloc[j,2]
        for element in CheckN:
            if DataToComp == element:
                ListeNNP.append(RefPrenom.index[j])
print(ListeNNP)

for i in range (0,len(DfListe.index)):
    DataToComp = DfListe.iloc[i,0]
    if type(DataToComp) == float:
        ListeNNN.append('')
    for j in range (0, len(RefNom.index)):
        CheckN = RefNom.iloc[j,1]
        for element in CheckN:
            if DataToComp == element:
                ListeNNN.append(RefNom.index[j])
print(ListeNNN)
'''
# Out:
# "\nListeNNN = []\nListeNNP = []\nfor i in range (0,len(DfListe.index)):\n    DataToComp = DfListe.iloc[i,1]\n    if type(DataToComp) == float:\n        ListeNNP.append('') \n    for j in range (0, len(RefPrenom.index)):\n        CheckN = RefPrenom.iloc[j,2]\n        for element in CheckN:\n            if DataToComp == element:\n                ListeNNP.append(RefPrenom.index[j])\nprint(ListeNNP)\n\nfor i in range (0,len(DfListe.index)):\n    DataToComp = DfListe.iloc[i,0]\n    if type(DataToComp) == float:\n        ListeNNN.append('')\n    for j in range (0, len(RefNom.index)):\n        CheckN = RefNom.iloc[j,1]\n        for element in CheckN:\n            if DataToComp == element:\n                ListeNNN.append(RefNom.index[j])\nprint(ListeNNN)\n"

# %%
print(len(ListeNNP))
print(len(ListeNNN))
print(len(DfListe.index))
print(DfListe.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2f4bb6b7b467> in <module>
# ----> 1 print(len(ListeNNP))
#       2 print(len(ListeNNN))
#       3 print(len(DfListe.index))
#       4 print(DfListe.index)
#
# NameError: name 'ListeNNP' is not defined

# %%
DfListe['NomNormalisé'] =  ListeNNN
DfListe['PrénomNormalisé'] = ListeNNP
DfListe

# %%
"""
dataframe[["nom","prénom"]].describe()
NomPrénom = dataframe[['nom', 'prénom']].to_csv(index=True)
print (NomPrénom)
with open ('../Tables/NomsPrénoms.csv','w') as Doc:
    Doc.write(NomPrénom)
import matplotlib.pyplot as plt
df2 = dataframe["Corporation"].value_counts()
df3 = dataframe['Poêle'].value_counts()
df2.plot.pie()
plt.show()
df4 = dataframe["nom"].value_counts()
df4
df4.plot.pie()
"""
